# %% [markdown]
# <a href="https://colab.research.google.com/github/eltongaspar/python/blob/Advpl/Pyhons_Senai_Aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01
# variaveis
p1 = float()
p2 = float()
p3 = float()
media = float()

# entrada de dados
p1 = float(input("Digite a primeira nota: "))
p2 = float(input("Digite a segunda nota: "))
p3 = float(input("Digite a terceira nota: "))

#calculos
nota = (p1 + p2 + p3) / 3
print(f"A média é : {nota:.2f}")
# Out:
# Digite a primeira nota: 10
# Digite a segunda nota: 10
# Digite a terceira nota: 10
# A média é : 10.00

# %%
# 02
#variaveis
cateto1 = float()
cateto2 = float()
hipotenusa = float()

#atribuindo valor a variavel
cateto1 = 4
cateto2 = 3

#calculos
hipotenusa = (cateto1 ** 2 + cateto2 ** 2) ** (1/2)
print(f"A hipotenusa é : {hipotenusa:.2f}")
# Out:
# A hipotenusa é : 5.00

# %%
# 03
#variaveis
salario = float()
aumento = float()
novo_salario = float()

#entrada de dados
salario = float(input("Digite o salario: "))
aumento = float(input("Digite o aumento: "))

#calculos
aumento = salario * (aumento / 100)
novo_salario = salario + aumento
print(f"O novo salario é : {novo_salario:.2f}")
# Out:
# Digite o salario: 100
# Digite o aumento: 5
# O novo salario é : 105.00

# %%
# 04
#importando bibliotecas
import math

#variaveis
pi = (math.pi)
raio = float()
altura = float()
volume = float()

#entrada de dados
raio = float(input("Digite o raio: "))
altura = float(input("Digite a altura: "))

#calculos
volume = pi * (raio ** 2) * altura
print(f"O volume é : {volume:.4f}")

print(f"{math.pi:.4f}")
# 3.141592653589793
# Out:
# Digite o raio: 3
# Digite a altura: 3
# O volume é : 84.8230
# 3.1416

# %%
import random

# --- Funções auxiliares (equivalentes às suas funções .prg) ---

import random

def GeraNumAleatMinMax(quantidade, minimo, maximo):
    """Gera uma lista de números aleatórios, permitindo duplicatas."""
    numeros = random.choices(range(minimo, maximo + 1), k=quantidade)
    return numeros


def MsgLoad(mensagem, qtde_msgs=1):
    """Simula a função MsgLoad do Clipper."""
    print(mensagem)

def GeraBarAuto(quantidade, minimo, maximo):
    """Gera um baralho ordenado."""
    baralho = []
    for i in range(minimo, maximo + 1):
        baralho.append(i)
    return baralho

def FuncaoTelaPergunt():
    """Perguntas para a Funcao Tela Parada e Tempo - Wait e Inkey"""

    lWait = False
    lInkey = False
    iWaittValid = 0
    iInkeytValid = 0
    iTempInkey = 1

    while iWaittValid != 1 and iWaittValid != 2:
        iWaittValid = int(input('Deseja ter Parada de Tela (Wait) - 1-Sim/2-Nao: '))

        if iWaittValid == 1:
            lWait = True
        elif iWaittValid == 2:
            lWait = False

    while iInkeytValid != 1 and iInkeytValid != 2:
        iInkeytValid = int(input('Deseja ter Tempo de Tela (Inkey) - 1-Sim/2-Nao: '))

        if iInkeytValid == 1:
            lInkey = True
            iTempInkey = int(input('Informe o Tempo de Espera de Tela em segundos: '))
        elif iInkeytValid == 2:
            lInkey = False

    return lWait, lInkey, iTempInkey



import time

def FuncaoTela(lWait=False, lInkey=False, iTempInkey=0):
  """Simulates the FuncaoTela function from Clipper.

  Args:
    lWait: If True, pauses execution and waits for a key press.
    lInkey: If True, reads a key press with a timeout.
    iTempInkey: Timeout in seconds for INKEY (only if lInkey is True).

  Returns:
    None
  """
  if lWait:
    input("Aperte uma Tecla para Continuar ")

  if lInkey:
    time.sleep(iTempInkey)
    # Note: Python's input() function doesn't have a direct equivalent
    # to Clipper's INKEY with a timeout. This implementation only waits
    # for the specified time and doesn't read a key press.
    # You might need a more sophisticated solution using libraries
    # like `msvcrt` (Windows) or `termios` (Linux/macOS) for
    # non-blocking key input with timeouts.

  return None


# --- Fim das funções auxiliares ---

def main():
    # Baralho (equivalente ao seu array multidimensional)
    baralho = [
        [101, 3, "A", "Copas"], [101, 4, "A", "Ouro"], [101, 5, "A", "Paus"], [101, 6, "A", "Espadas"],
        [102, 3, "2", "Copas"], [102, 4, "2", "Ouro"], [102, 5, "2", "Paus"], [102, 6, "2", "Espadas"],
        [103, 3, "3", "Copas"], [103, 4, "3", "Ouro"], [103, 5, "3", "Paus"], [103, 6, "3", "Espadas"],
        [104, 3, "4", "Copas"], [104, 4, "4", "Ouro"], [104, 5, "4", "Paus"], [104, 6, "4", "Espadas"],
        [105, 3, "5", "Copas"], [105, 4, "5", "Ouro"], [105, 5, "5", "Paus"], [105, 6, "5", "Espadas"],
        [106, 3, "4", "Copas"], [106, 4, "6", "Ouro"], [106, 5, "6", "Paus"], [106, 6, "6", "Espadas"],
        [107, 3, "7", "Copas"], [107, 4, "7", "Ouro"], [107, 5, "7", "Paus"], [107, 6, "7", "Espadas"],
        [108, 3, "8", "Copas"], [108, 4, "8", "Ouro"], [108, 5, "8", "Paus"], [108, 6, "8", "Espadas"],
        [109, 3, "9", "Copas"], [109, 4, "9", "Ouro"], [109, 5, "9", "Paus"], [109, 6, "9", "Espadas"],
        [110, 3, "10", "Copas"], [110, 4, "10", "Ouro"], [110, 5, "10", "Paus"], [110, 6, "10", "Espadas"],
        [111, 3, "Q", "Copas"], [111, 4, "Q", "Ouro"], [111, 5, "Q", "Paus"], [111, 6, "Q", "Espadas"],
        [112, 3, "J", "Copas"], [112, 4, "J", "Ouro"], [112, 5, "J", "Paus"], [112, 6, "J", "Espadas"],
        [113, 3, "K", "Copas"], [113, 4, "K", "Ouro"], [113, 5, "K", "Paus"], [113, 6, "K", "Espadas"]
    ]

    infinito = 0
    while infinito != 1 and infinito != 2:
        infinito = int(input('Deseja ativar Modo Loop: 1-Sim/2-Nao: '))

        if infinito == 1:
            lInfinit = True

        if infinito == 2:
            lInfinit = False

    if not lInfinit or lInfinit == True:
        FuncaoTelaPergunt()
        FuncaoTela()

    while lInfinit:
        # Gerando Baralho Auto
        MsgLoad('Criando Baralho Auto', 5)
        baralho_gerado = GeraBarAuto(13, 101, 113)

        # Exibe Baralho
        MsgLoad('Carregando Baralhos', 5)
        print(baralho)

        FuncaoTela()

        # Embaralhando Cartas
        MsgLoad('Embaralhando Cartas Resultado', 5)
        cartas_embaralhadas = GeraNumAleatMinMax(52, 101, 113)

        FuncaoTela()

        # Embaralhando Naipes
        MsgLoad('Embaralhando Naipes', 5)
        naipes_embaralhados = GeraNumAleatMinMax(52, 3, 6)

        FuncaoTela()

        # Cartas Embaralhadas (Cartas + Naipes)
        cartas_embaralhadas_completo = []
        for i in range(52):
            carta = cartas_embaralhadas[i]
            naipe = naipes_embaralhados[i]

            # Encontrando a descrição da carta e naipe
            for carta_info in baralho:
                if carta_info[0] == carta and carta_info[1] == naipe:
                    cCartaDesc = carta_info[2]
                    cNaipeDesc = carta_info[3]
                    break

            cartas_embaralhadas_completo.append([carta, naipe, cCartaDesc, cNaipeDesc])

        MsgLoad('Carregando Baralhos Embaralhados', 5)
        print(cartas_embaralhadas_completo)

        FuncaoTela()

        # Embaralhando 21 Cartas
        MsgLoad('Cartas Embaralhadas (21 Cartas)', 5)
        for i in range(21):
            print(cartas_embaralhadas_completo[i])

        FuncaoTela()

        # Embaralhando 21 Cartas (Matriz 7x3)
        matriz_cartas = []
        indice_carta = 20
        for i in range(3):
            linha = []
            for j in range(7):
                linha.append(cartas_embaralhadas_completo[indice_carta])
                indice_carta -= 1
            matriz_cartas.append(linha)

        MsgLoad('Cartas Embaralhadas (21 Cartas Matriz 7x3)', 5)
        print(matriz_cartas)

        FuncaoTela()

        # Pesquisa de Carta (Automatizada)
        MsgLoad('Pesquisa Auto - Carta Aleatoria', 5)
        carta_pesquisa = random.randint(101, 113)
        print(f"Carta para pesquisa: {carta_pesquisa}")

        MsgLoad('Pesquisa Auto - Naipe Aleatoria', 5)
        naipe_pesquisa = random.randint(3, 6)
        print(f"Naipe para pesquisa: {naipe_pesquisa}")

        FuncaoTela()

        # Encontrando a posição da carta na lista
        posicao_carta = -1  # Initialize with a default value
        for i, carta_info in enumerate(cartas_embaralhadas_completo):
            if carta_info[0] == carta_pesquisa and carta_info[1] == naipe_pesquisa:
                posicao_carta = i
                break

        if posicao_carta != -1:  # Check if the card was found
            print("Posicao Matriz")
            print(posicao_carta)

            # ... (rest of your code to handle the found card)
        else:
            print(f"Carta {carta_pesquisa} de {naipe_pesquisa} não encontrada no baralho.")


        print("Posicao Matriz")
        print(posicao_carta)

        FuncaoTela()

        print("Cartas")
        print(cartas_embaralhadas_completo[posicao_carta])

        FuncaoTela()

        # Troca de Carta (Automatizada)
        MsgLoad('Troca Auto - Carta Aleatoria', 5)
        nova_carta = random.randint(101, 113)
        print(f"Nova carta: {nova_carta}")

        MsgLoad('Troca Auto - Naipe Aleatoria', 5)
        novo_naipe = random.randint(3, 6)
        print(f"Novo naipe: {novo_naipe}")

        FuncaoTela()

        # Encontrando a nova carta no baralho
        for carta_info in baralho:
            if carta_info[0] == nova_carta and carta_info[1] == novo_naipe:
                nova_carta_info = carta_info
                break

        # Substituindo a carta na matriz
        if 0 <= posicao_carta < len(matriz_cartas) * len(matriz_cartas[0]):  # Check if posicao_carta is within bounds
            matriz_cartas[posicao_carta // 7][posicao_carta % 7] = nova_carta_info
        else:
            print(f"Posição da carta inválida: {posicao_carta}")

        MsgLoad('Cartas Trocadas', 5)
        print('Posicao')
        print(posicao_carta)

        FuncaoTela()

        print('Cartas Trocadas')
        print(matriz_cartas[0][0])  # Posição 1

        FuncaoTela()

        MsgLoad('Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)', 5)
        print(matriz_cartas)

        FuncaoTela()

        # Exibindo as primeiras 11 cartas
        MsgLoad('Cartas Embaralhadas (21 Cartas)', 5)
        for i in range(11):
            print(cartas_embaralhadas_completo[i])

        FuncaoTela()

        # Exibindo todas as cartas do baralho
        MsgLoad('Cartas do Baralho', 5)
        for carta_info in baralho:
            print(carta_info)

        FuncaoTela()

        # Exibindo todas as cartas embaralhadas
        MsgLoad('Cartas Embaralhadas', 5)
        for carta_info in cartas_embaralhadas_completo:
            print(carta_info)

        FuncaoTela()

if __name__ == "__main__":
    main()
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[108, 6, '8', 'Espadas'], [104, 4, '4', 'Ouro'], [113, 5, 'K', 'Paus'], [111, 5, 'Q', 'Paus'], [110, 6, '10', 'Espadas'], [108, 6, '8', 'Espadas'], [113, 6, 'K', 'Espadas']], [[109, 3, '9', 'Copas'], [112, 5, 'J', 'Paus'], [101, 5, 'A', 'Paus'], [108, 5, '8', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [103, 6, '3', 'Espadas']], [[109, 3, '9', 'Copas'], [107, 6, '7', 'Espadas'], [105, 5, '5', 'Paus'], [101, 3, 'A', 'Copas'], [113, 4, 'K', 'Ouro'], [110, 3, '10', 'Copas'], [102, 4, '2', 'Ouro']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 103
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 3
# Carta 103 de 3 não encontrada no baralho.
# Posicao Matriz
# -1
# Cartas
# [109, 5, '9', 'Paus']
# Troca Auto - Carta Aleatoria
# Nova carta: 102
# Troca Auto - Naipe Aleatoria
# Novo naipe: 6
# Posição da carta inválida: -1
# Cartas Trocadas
# Posicao
# -1
# Cartas Trocadas
# [108, 6, '8', 'Espadas']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[108, 6, '8', 'Espadas'], [104, 4, '4', 'Ouro'], [113, 5, 'K', 'Paus'], [111, 5, 'Q', 'Paus'], [110, 6, '10', 'Espadas'], [108, 6, '8', 'Espadas'], [113, 6, 'K', 'Espadas']], [[109, 3, '9', 'Copas'], [112, 5, 'J', 'Paus'], [101, 5, 'A', 'Paus'], [108, 5, '8', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [103, 6, '3', 'Espadas']], [[109, 3, '9', 'Copas'], [107, 6, '7', 'Espadas'], [105, 5, '5', 'Paus'], [101, 3, 'A', 'Copas'], [113, 4, 'K', 'Ouro'], [110, 3, '10', 'Copas'], [102, 4, '2', 'Ouro']]]
# Cartas Embaralhadas (21 Cartas)
# [102, 4, '2', 'Ouro']
# [110, 3, '10', 'Copas']
# [113, 4, 'K', 'Ouro']
# [101, 3, 'A', 'Copas']
# [105, 5, '5', 'Paus']
# [107, 6, '7', 'Espadas']
# [109, 3, '9', 'Copas']
# [103, 6, '3', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [110, 6, '10', 'Espadas']
# [108, 5, '8', 'Paus']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [102, 4, '2', 'Ouro']
# [110, 3, '10', 'Copas']
# [113, 4, 'K', 'Ouro']
# [101, 3, 'A', 'Copas']
# [105, 5, '5', 'Paus']
# [107, 6, '7', 'Espadas']
# [109, 3, '9', 'Copas']
# [103, 6, '3', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [110, 6, '10', 'Espadas']
# [108, 5, '8', 'Paus']
# [101, 5, 'A', 'Paus']
# [112, 5, 'J', 'Paus']
# [109, 3, '9', 'Copas']
# [113, 6, 'K', 'Espadas']
# [108, 6, '8', 'Espadas']
# [110, 6, '10', 'Espadas']
# [111, 5, 'Q', 'Paus']
# [113, 5, 'K', 'Paus']
# [104, 4, '4', 'Ouro']
# [108, 6, '8', 'Espadas']
# [101, 4, 'A', 'Ouro']
# [113, 3, 'K', 'Copas']
# [101, 6, 'A', 'Espadas']
# [107, 3, '7', 'Copas']
# [113, 3, 'K', 'Copas']
# [105, 5, '5', 'Paus']
# [101, 3, 'A', 'Copas']
# [109, 4, '9', 'Ouro']
# [104, 6, '4', 'Espadas']
# [107, 4, '7', 'Ouro']
# [110, 3, '10', 'Copas']
# [113, 6, 'K', 'Espadas']
# [104, 3, '4', 'Copas']
# [109, 6, '9', 'Espadas']
# [108, 6, '8', 'Espadas']
# [109, 6, '9', 'Espadas']
# [108, 6, '8', 'Espadas']
# [110, 4, '10', 'Ouro']
# [101, 3, 'A', 'Copas']
# [109, 3, '9', 'Copas']
# [110, 3, '10', 'Copas']
# [113, 6, 'K', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [112, 6, 'J', 'Espadas']
# [105, 4, '5', 'Ouro']
# [107, 6, '7', 'Espadas']
# [109, 5, '9', 'Paus']
# [105, 5, '5', 'Paus']
# [103, 5, '3', 'Paus']
# [102, 3, '2', 'Copas']
# [109, 5, '9', 'Paus']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[111, 5, 'Q', 'Paus'], [112, 6, 'J', 'Espadas'], [101, 5, 'A', 'Paus'], [108, 3, '8', 'Copas'], [106, 4, '6', 'Ouro'], [109, 4, '9', 'Ouro'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [109, 3, '9', 'Copas'], [111, 3, 'Q', 'Copas'], [107, 6, '7', 'Espadas'], [101, 5, 'A', 'Paus'], [105, 4, '5', 'Ouro'], [110, 4, '10', 'Ouro'], [101, 5, 'A', 'Paus'], [106, 3, '4', 'Copas'], [104, 6, '4', 'Espadas'], [113, 4, 'K', 'Ouro'], [108, 3, '8', 'Copas'], [103, 3, '3', 'Copas'], [102, 5, '2', 'Paus'], [104, 5, '4', 'Paus'], [104, 4, '4', 'Ouro'], [109, 4, '9', 'Ouro'], [112, 4, 'J', 'Ouro'], [112, 4, 'J', 'Ouro'], [112, 6, 'J', 'Espadas'], [108, 3, '8', 'Copas'], [111, 3, 'Q', 'Copas'], [106, 3, '4', 'Copas'], [105, 6, '5', 'Espadas'], [107, 5, '7', 'Paus'], [109, 6, '9', 'Espadas'], [102, 4, '2', 'Ouro'], [106, 4, '6', 'Ouro'], [112, 4, 'J', 'Ouro'], [102, 5, '2', 'Paus'], [113, 6, 'K', 'Espadas'], [108, 6, '8', 'Espadas'], [113, 4, 'K', 'Ouro'], [104, 4, '4', 'Ouro'], [110, 5, '10', 'Paus'], [113, 5, 'K', 'Paus'], [112, 6, 'J', 'Espadas'], [105, 3, '5', 'Copas'], [103, 5, '3', 'Paus'], [103, 5, '3', 'Paus'], [101, 3, 'A', 'Copas'], [102, 4, '2', 'Ouro'], [106, 4, '6', 'Ouro'], [113, 5, 'K', 'Paus'], [112, 6, 'J', 'Espadas']]
# Cartas Embaralhadas (21 Cartas)
# [111, 5, 'Q', 'Paus']
# [112, 6, 'J', 'Espadas']
# [101, 5, 'A', 'Paus']
# [108, 3, '8', 'Copas']
# [106, 4, '6', 'Ouro']
# [109, 4, '9', 'Ouro']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [109, 3, '9', 'Copas']
# [111, 3, 'Q', 'Copas']
# [107, 6, '7', 'Espadas']
# [101, 5, 'A', 'Paus']
# [105, 4, '5', 'Ouro']
# [110, 4, '10', 'Ouro']
# [101, 5, 'A', 'Paus']
# [106, 3, '4', 'Copas']
# [104, 6, '4', 'Espadas']
# [113, 4, 'K', 'Ouro']
# [108, 3, '8', 'Copas']
# [103, 3, '3', 'Copas']
# [102, 5, '2', 'Paus']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[102, 5, '2', 'Paus'], [103, 3, '3', 'Copas'], [108, 3, '8', 'Copas'], [113, 4, 'K', 'Ouro'], [104, 6, '4', 'Espadas'], [106, 3, '4', 'Copas'], [101, 5, 'A', 'Paus']], [[110, 4, '10', 'Ouro'], [105, 4, '5', 'Ouro'], [101, 5, 'A', 'Paus'], [107, 6, '7', 'Espadas'], [111, 3, 'Q', 'Copas'], [109, 3, '9', 'Copas'], [107, 4, '7', 'Ouro']], [[107, 3, '7', 'Copas'], [109, 4, '9', 'Ouro'], [106, 4, '6', 'Ouro'], [108, 3, '8', 'Copas'], [101, 5, 'A', 'Paus'], [112, 6, 'J', 'Espadas'], [111, 5, 'Q', 'Paus']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 108
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 6
# Posicao Matriz
# 38
# Posicao Matriz
# 38
# Cartas
# [108, 6, '8', 'Espadas']
# Troca Auto - Carta Aleatoria
# Nova carta: 107
# Troca Auto - Naipe Aleatoria
# Novo naipe: 5
# Posição da carta inválida: 38
# Cartas Trocadas
# Posicao
# 38
# Cartas Trocadas
# [102, 5, '2', 'Paus']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[102, 5, '2', 'Paus'], [103, 3, '3', 'Copas'], [108, 3, '8', 'Copas'], [113, 4, 'K', 'Ouro'], [104, 6, '4', 'Espadas'], [106, 3, '4', 'Copas'], [101, 5, 'A', 'Paus']], [[110, 4, '10', 'Ouro'], [105, 4, '5', 'Ouro'], [101, 5, 'A', 'Paus'], [107, 6, '7', 'Espadas'], [111, 3, 'Q', 'Copas'], [109, 3, '9', 'Copas'], [107, 4, '7', 'Ouro']], [[107, 3, '7', 'Copas'], [109, 4, '9', 'Ouro'], [106, 4, '6', 'Ouro'], [108, 3, '8', 'Copas'], [101, 5, 'A', 'Paus'], [112, 6, 'J', 'Espadas'], [111, 5, 'Q', 'Paus']]]
# Cartas Embaralhadas (21 Cartas)
# [111, 5, 'Q', 'Paus']
# [112, 6, 'J', 'Espadas']
# [101, 5, 'A', 'Paus']
# [108, 3, '8', 'Copas']
# [106, 4, '6', 'Ouro']
# [109, 4, '9', 'Ouro']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [109, 3, '9', 'Copas']
# [111, 3, 'Q', 'Copas']
# [107, 6, '7', 'Espadas']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [111, 5, 'Q', 'Paus']
# [112, 6, 'J', 'Espadas']
# [101, 5, 'A', 'Paus']
# [108, 3, '8', 'Copas']
# [106, 4, '6', 'Ouro']
# [109, 4, '9', 'Ouro']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [109, 3, '9', 'Copas']
# [111, 3, 'Q', 'Copas']
# [107, 6, '7', 'Espadas']
# [101, 5, 'A', 'Paus']
# [105, 4, '5', 'Ouro']
# [110, 4, '10', 'Ouro']
# [101, 5, 'A', 'Paus']
# [106, 3, '4', 'Copas']
# [104, 6, '4', 'Espadas']
# [113, 4, 'K', 'Ouro']
# [108, 3, '8', 'Copas']
# [103, 3, '3', 'Copas']
# [102, 5, '2', 'Paus']
# [104, 5, '4', 'Paus']
# [104, 4, '4', 'Ouro']
# [109, 4, '9', 'Ouro']
# [112, 4, 'J', 'Ouro']
# [112, 4, 'J', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [108, 3, '8', 'Copas']
# [111, 3, 'Q', 'Copas']
# [106, 3, '4', 'Copas']
# [105, 6, '5', 'Espadas']
# [107, 5, '7', 'Paus']
# [109, 6, '9', 'Espadas']
# [102, 4, '2', 'Ouro']
# [106, 4, '6', 'Ouro']
# [112, 4, 'J', 'Ouro']
# [102, 5, '2', 'Paus']
# [113, 6, 'K', 'Espadas']
# [108, 6, '8', 'Espadas']
# [113, 4, 'K', 'Ouro']
# [104, 4, '4', 'Ouro']
# [110, 5, '10', 'Paus']
# [113, 5, 'K', 'Paus']
# [112, 6, 'J', 'Espadas']
# [105, 3, '5', 'Copas']
# [103, 5, '3', 'Paus']
# [103, 5, '3', 'Paus']
# [101, 3, 'A', 'Copas']
# [102, 4, '2', 'Ouro']
# [106, 4, '6', 'Ouro']
# [113, 5, 'K', 'Paus']
# [112, 6, 'J', 'Espadas']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[110, 3, '10', 'Copas'], [113, 6, 'K', 'Espadas'], [107, 6, '7', 'Espadas'], [106, 5, '6', 'Paus'], [106, 3, '4', 'Copas'], [101, 3, 'A', 'Copas'], [101, 6, 'A', 'Espadas'], [105, 5, '5', 'Paus'], [106, 6, '6', 'Espadas'], [113, 5, 'K', 'Paus'], [103, 6, '3', 'Espadas'], [110, 6, '10', 'Espadas'], [109, 5, '9', 'Paus'], [112, 4, 'J', 'Ouro'], [112, 6, 'J', 'Espadas'], [102, 4, '2', 'Ouro'], [102, 4, '2', 'Ouro'], [104, 4, '4', 'Ouro'], [101, 6, 'A', 'Espadas'], [102, 4, '2', 'Ouro'], [103, 6, '3', 'Espadas'], [108, 3, '8', 'Copas'], [111, 3, 'Q', 'Copas'], [104, 5, '4', 'Paus'], [105, 5, '5', 'Paus'], [101, 3, 'A', 'Copas'], [107, 4, '7', 'Ouro'], [111, 4, 'Q', 'Ouro'], [102, 4, '2', 'Ouro'], [106, 4, '6', 'Ouro'], [110, 4, '10', 'Ouro'], [109, 4, '9', 'Ouro'], [107, 4, '7', 'Ouro'], [103, 5, '3', 'Paus'], [103, 5, '3', 'Paus'], [112, 5, 'J', 'Paus'], [111, 3, 'Q', 'Copas'], [111, 6, 'Q', 'Espadas'], [113, 4, 'K', 'Ouro'], [108, 4, '8', 'Ouro'], [113, 3, 'K', 'Copas'], [104, 4, '4', 'Ouro'], [107, 5, '7', 'Paus'], [109, 5, '9', 'Paus'], [102, 6, '2', 'Espadas'], [112, 6, 'J', 'Espadas'], [104, 6, '4', 'Espadas'], [113, 4, 'K', 'Ouro'], [104, 5, '4', 'Paus'], [108, 5, '8', 'Paus'], [107, 5, '7', 'Paus'], [103, 5, '3', 'Paus']]
# Cartas Embaralhadas (21 Cartas)
# [110, 3, '10', 'Copas']
# [113, 6, 'K', 'Espadas']
# [107, 6, '7', 'Espadas']
# [106, 5, '6', 'Paus']
# [106, 3, '4', 'Copas']
# [101, 3, 'A', 'Copas']
# [101, 6, 'A', 'Espadas']
# [105, 5, '5', 'Paus']
# [106, 6, '6', 'Espadas']
# [113, 5, 'K', 'Paus']
# [103, 6, '3', 'Espadas']
# [110, 6, '10', 'Espadas']
# [109, 5, '9', 'Paus']
# [112, 4, 'J', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [102, 4, '2', 'Ouro']
# [102, 4, '2', 'Ouro']
# [104, 4, '4', 'Ouro']
# [101, 6, 'A', 'Espadas']
# [102, 4, '2', 'Ouro']
# [103, 6, '3', 'Espadas']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[103, 6, '3', 'Espadas'], [102, 4, '2', 'Ouro'], [101, 6, 'A', 'Espadas'], [104, 4, '4', 'Ouro'], [102, 4, '2', 'Ouro'], [102, 4, '2', 'Ouro'], [112, 6, 'J', 'Espadas']], [[112, 4, 'J', 'Ouro'], [109, 5, '9', 'Paus'], [110, 6, '10', 'Espadas'], [103, 6, '3', 'Espadas'], [113, 5, 'K', 'Paus'], [106, 6, '6', 'Espadas'], [105, 5, '5', 'Paus']], [[101, 6, 'A', 'Espadas'], [101, 3, 'A', 'Copas'], [106, 3, '4', 'Copas'], [106, 5, '6', 'Paus'], [107, 6, '7', 'Espadas'], [113, 6, 'K', 'Espadas'], [110, 3, '10', 'Copas']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 113
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 4
# Posicao Matriz
# 38
# Posicao Matriz
# 38
# Cartas
# [113, 4, 'K', 'Ouro']
# Troca Auto - Carta Aleatoria
# Nova carta: 102
# Troca Auto - Naipe Aleatoria
# Novo naipe: 5
# Posição da carta inválida: 38
# Cartas Trocadas
# Posicao
# 38
# Cartas Trocadas
# [103, 6, '3', 'Espadas']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[103, 6, '3', 'Espadas'], [102, 4, '2', 'Ouro'], [101, 6, 'A', 'Espadas'], [104, 4, '4', 'Ouro'], [102, 4, '2', 'Ouro'], [102, 4, '2', 'Ouro'], [112, 6, 'J', 'Espadas']], [[112, 4, 'J', 'Ouro'], [109, 5, '9', 'Paus'], [110, 6, '10', 'Espadas'], [103, 6, '3', 'Espadas'], [113, 5, 'K', 'Paus'], [106, 6, '6', 'Espadas'], [105, 5, '5', 'Paus']], [[101, 6, 'A', 'Espadas'], [101, 3, 'A', 'Copas'], [106, 3, '4', 'Copas'], [106, 5, '6', 'Paus'], [107, 6, '7', 'Espadas'], [113, 6, 'K', 'Espadas'], [110, 3, '10', 'Copas']]]
# Cartas Embaralhadas (21 Cartas)
# [110, 3, '10', 'Copas']
# [113, 6, 'K', 'Espadas']
# [107, 6, '7', 'Espadas']
# [106, 5, '6', 'Paus']
# [106, 3, '4', 'Copas']
# [101, 3, 'A', 'Copas']
# [101, 6, 'A', 'Espadas']
# [105, 5, '5', 'Paus']
# [106, 6, '6', 'Espadas']
# [113, 5, 'K', 'Paus']
# [103, 6, '3', 'Espadas']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [110, 3, '10', 'Copas']
# [113, 6, 'K', 'Espadas']
# [107, 6, '7', 'Espadas']
# [106, 5, '6', 'Paus']
# [106, 3, '4', 'Copas']
# [101, 3, 'A', 'Copas']
# [101, 6, 'A', 'Espadas']
# [105, 5, '5', 'Paus']
# [106, 6, '6', 'Espadas']
# [113, 5, 'K', 'Paus']
# [103, 6, '3', 'Espadas']
# [110, 6, '10', 'Espadas']
# [109, 5, '9', 'Paus']
# [112, 4, 'J', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [102, 4, '2', 'Ouro']
# [102, 4, '2', 'Ouro']
# [104, 4, '4', 'Ouro']
# [101, 6, 'A', 'Espadas']
# [102, 4, '2', 'Ouro']
# [103, 6, '3', 'Espadas']
# [108, 3, '8', 'Copas']
# [111, 3, 'Q', 'Copas']
# [104, 5, '4', 'Paus']
# [105, 5, '5', 'Paus']
# [101, 3, 'A', 'Copas']
# [107, 4, '7', 'Ouro']
# [111, 4, 'Q', 'Ouro']
# [102, 4, '2', 'Ouro']
# [106, 4, '6', 'Ouro']
# [110, 4, '10', 'Ouro']
# [109, 4, '9', 'Ouro']
# [107, 4, '7', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 5, '3', 'Paus']
# [112, 5, 'J', 'Paus']
# [111, 3, 'Q', 'Copas']
# [111, 6, 'Q', 'Espadas']
# [113, 4, 'K', 'Ouro']
# [108, 4, '8', 'Ouro']
# [113, 3, 'K', 'Copas']
# [104, 4, '4', 'Ouro']
# [107, 5, '7', 'Paus']
# [109, 5, '9', 'Paus']
# [102, 6, '2', 'Espadas']
# [112, 6, 'J', 'Espadas']
# [104, 6, '4', 'Espadas']
# [113, 4, 'K', 'Ouro']
# [104, 5, '4', 'Paus']
# [108, 5, '8', 'Paus']
# [107, 5, '7', 'Paus']
# [103, 5, '3', 'Paus']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[101, 3, 'A', 'Copas'], [111, 4, 'Q', 'Ouro'], [104, 6, '4', 'Espadas'], [103, 3, '3', 'Copas'], [106, 6, '6', 'Espadas'], [103, 5, '3', 'Paus'], [108, 6, '8', 'Espadas'], [102, 4, '2', 'Ouro'], [112, 4, 'J', 'Ouro'], [105, 3, '5', 'Copas'], [111, 3, 'Q', 'Copas'], [107, 3, '7', 'Copas'], [108, 3, '8', 'Copas'], [112, 5, 'J', 'Paus'], [112, 3, 'J', 'Copas'], [112, 6, 'J', 'Espadas'], [103, 4, '3', 'Ouro'], [111, 3, 'Q', 'Copas'], [110, 4, '10', 'Ouro'], [105, 4, '5', 'Ouro'], [107, 5, '7', 'Paus'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [109, 6, '9', 'Espadas'], [106, 6, '6', 'Espadas'], [113, 4, 'K', 'Ouro'], [101, 5, 'A', 'Paus'], [106, 6, '6', 'Espadas'], [104, 3, '4', 'Copas'], [107, 5, '7', 'Paus'], [111, 6, 'Q', 'Espadas'], [110, 6, '10', 'Espadas'], [108, 5, '8', 'Paus'], [104, 5, '4', 'Paus'], [108, 5, '8', 'Paus'], [109, 5, '9', 'Paus'], [112, 6, 'J', 'Espadas'], [108, 4, '8', 'Ouro'], [102, 4, '2', 'Ouro'], [106, 6, '6', 'Espadas'], [108, 5, '8', 'Paus'], [110, 5, '10', 'Paus'], [101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [103, 6, '3', 'Espadas'], [107, 5, '7', 'Paus'], [103, 3, '3', 'Copas'], [104, 5, '4', 'Paus'], [107, 3, '7', 'Copas'], [108, 4, '8', 'Ouro'], [107, 5, '7', 'Paus'], [102, 5, '2', 'Paus']]
# Cartas Embaralhadas (21 Cartas)
# [101, 3, 'A', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [104, 6, '4', 'Espadas']
# [103, 3, '3', 'Copas']
# [106, 6, '6', 'Espadas']
# [103, 5, '3', 'Paus']
# [108, 6, '8', 'Espadas']
# [102, 4, '2', 'Ouro']
# [112, 4, 'J', 'Ouro']
# [105, 3, '5', 'Copas']
# [111, 3, 'Q', 'Copas']
# [107, 3, '7', 'Copas']
# [108, 3, '8', 'Copas']
# [112, 5, 'J', 'Paus']
# [112, 3, 'J', 'Copas']
# [112, 6, 'J', 'Espadas']
# [103, 4, '3', 'Ouro']
# [111, 3, 'Q', 'Copas']
# [110, 4, '10', 'Ouro']
# [105, 4, '5', 'Ouro']
# [107, 5, '7', 'Paus']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[107, 5, '7', 'Paus'], [105, 4, '5', 'Ouro'], [110, 4, '10', 'Ouro'], [111, 3, 'Q', 'Copas'], [103, 4, '3', 'Ouro'], [112, 6, 'J', 'Espadas'], [112, 3, 'J', 'Copas']], [[112, 5, 'J', 'Paus'], [108, 3, '8', 'Copas'], [107, 3, '7', 'Copas'], [111, 3, 'Q', 'Copas'], [105, 3, '5', 'Copas'], [112, 4, 'J', 'Ouro'], [102, 4, '2', 'Ouro']], [[108, 6, '8', 'Espadas'], [103, 5, '3', 'Paus'], [106, 6, '6', 'Espadas'], [103, 3, '3', 'Copas'], [104, 6, '4', 'Espadas'], [111, 4, 'Q', 'Ouro'], [101, 3, 'A', 'Copas']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 113
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 4
# Posicao Matriz
# 25
# Posicao Matriz
# 25
# Cartas
# [113, 4, 'K', 'Ouro']
# Troca Auto - Carta Aleatoria
# Nova carta: 104
# Troca Auto - Naipe Aleatoria
# Novo naipe: 3
# Posição da carta inválida: 25
# Cartas Trocadas
# Posicao
# 25
# Cartas Trocadas
# [107, 5, '7', 'Paus']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[107, 5, '7', 'Paus'], [105, 4, '5', 'Ouro'], [110, 4, '10', 'Ouro'], [111, 3, 'Q', 'Copas'], [103, 4, '3', 'Ouro'], [112, 6, 'J', 'Espadas'], [112, 3, 'J', 'Copas']], [[112, 5, 'J', 'Paus'], [108, 3, '8', 'Copas'], [107, 3, '7', 'Copas'], [111, 3, 'Q', 'Copas'], [105, 3, '5', 'Copas'], [112, 4, 'J', 'Ouro'], [102, 4, '2', 'Ouro']], [[108, 6, '8', 'Espadas'], [103, 5, '3', 'Paus'], [106, 6, '6', 'Espadas'], [103, 3, '3', 'Copas'], [104, 6, '4', 'Espadas'], [111, 4, 'Q', 'Ouro'], [101, 3, 'A', 'Copas']]]
# Cartas Embaralhadas (21 Cartas)
# [101, 3, 'A', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [104, 6, '4', 'Espadas']
# [103, 3, '3', 'Copas']
# [106, 6, '6', 'Espadas']
# [103, 5, '3', 'Paus']
# [108, 6, '8', 'Espadas']
# [102, 4, '2', 'Ouro']
# [112, 4, 'J', 'Ouro']
# [105, 3, '5', 'Copas']
# [111, 3, 'Q', 'Copas']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [101, 3, 'A', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [104, 6, '4', 'Espadas']
# [103, 3, '3', 'Copas']
# [106, 6, '6', 'Espadas']
# [103, 5, '3', 'Paus']
# [108, 6, '8', 'Espadas']
# [102, 4, '2', 'Ouro']
# [112, 4, 'J', 'Ouro']
# [105, 3, '5', 'Copas']
# [111, 3, 'Q', 'Copas']
# [107, 3, '7', 'Copas']
# [108, 3, '8', 'Copas']
# [112, 5, 'J', 'Paus']
# [112, 3, 'J', 'Copas']
# [112, 6, 'J', 'Espadas']
# [103, 4, '3', 'Ouro']
# [111, 3, 'Q', 'Copas']
# [110, 4, '10', 'Ouro']
# [105, 4, '5', 'Ouro']
# [107, 5, '7', 'Paus']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [109, 6, '9', 'Espadas']
# [106, 6, '6', 'Espadas']
# [113, 4, 'K', 'Ouro']
# [101, 5, 'A', 'Paus']
# [106, 6, '6', 'Espadas']
# [104, 3, '4', 'Copas']
# [107, 5, '7', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [110, 6, '10', 'Espadas']
# [108, 5, '8', 'Paus']
# [104, 5, '4', 'Paus']
# [108, 5, '8', 'Paus']
# [109, 5, '9', 'Paus']
# [112, 6, 'J', 'Espadas']
# [108, 4, '8', 'Ouro']
# [102, 4, '2', 'Ouro']
# [106, 6, '6', 'Espadas']
# [108, 5, '8', 'Paus']
# [110, 5, '10', 'Paus']
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [103, 6, '3', 'Espadas']
# [107, 5, '7', 'Paus']
# [103, 3, '3', 'Copas']
# [104, 5, '4', 'Paus']
# [107, 3, '7', 'Copas']
# [108, 4, '8', 'Ouro']
# [107, 5, '7', 'Paus']
# [102, 5, '2', 'Paus']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[102, 6, '2', 'Espadas'], [111, 4, 'Q', 'Ouro'], [109, 6, '9', 'Espadas'], [109, 6, '9', 'Espadas'], [104, 3, '4', 'Copas'], [103, 3, '3', 'Copas'], [104, 5, '4', 'Paus'], [103, 4, '3', 'Ouro'], [110, 4, '10', 'Ouro'], [111, 4, 'Q', 'Ouro'], [103, 4, '3', 'Ouro'], [112, 6, 'J', 'Espadas'], [101, 3, 'A', 'Copas'], [110, 5, '10', 'Paus'], [110, 3, '10', 'Copas'], [112, 6, 'J', 'Espadas'], [107, 6, '7', 'Espadas'], [102, 5, '2', 'Paus'], [102, 3, '2', 'Copas'], [109, 3, '9', 'Copas'], [110, 5, '10', 'Paus'], [102, 6, '2', 'Espadas'], [109, 6, '9', 'Espadas'], [104, 3, '4', 'Copas'], [112, 5, 'J', 'Paus'], [107, 5, '7', 'Paus'], [110, 5, '10', 'Paus'], [106, 4, '6', 'Ouro'], [107, 4, '7', 'Ouro'], [107, 4, '7', 'Ouro'], [111, 5, 'Q', 'Paus'], [110, 5, '10', 'Paus'], [108, 6, '8', 'Espadas'], [106, 5, '6', 'Paus'], [101, 6, 'A', 'Espadas'], [113, 3, 'K', 'Copas'], [108, 6, '8', 'Espadas'], [106, 5, '6', 'Paus'], [112, 6, 'J', 'Espadas'], [105, 4, '5', 'Ouro'], [110, 6, '10', 'Espadas'], [104, 3, '4', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 6, 'J', 'Espadas'], [108, 6, '8', 'Espadas'], [106, 6, '6', 'Espadas'], [112, 3, 'J', 'Copas'], [111, 5, 'Q', 'Paus'], [107, 6, '7', 'Espadas'], [110, 3, '10', 'Copas'], [106, 4, '6', 'Ouro'], [102, 3, '2', 'Copas']]
# Cartas Embaralhadas (21 Cartas)
# [102, 6, '2', 'Espadas']
# [111, 4, 'Q', 'Ouro']
# [109, 6, '9', 'Espadas']
# [109, 6, '9', 'Espadas']
# [104, 3, '4', 'Copas']
# [103, 3, '3', 'Copas']
# [104, 5, '4', 'Paus']
# [103, 4, '3', 'Ouro']
# [110, 4, '10', 'Ouro']
# [111, 4, 'Q', 'Ouro']
# [103, 4, '3', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [101, 3, 'A', 'Copas']
# [110, 5, '10', 'Paus']
# [110, 3, '10', 'Copas']
# [112, 6, 'J', 'Espadas']
# [107, 6, '7', 'Espadas']
# [102, 5, '2', 'Paus']
# [102, 3, '2', 'Copas']
# [109, 3, '9', 'Copas']
# [110, 5, '10', 'Paus']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[110, 5, '10', 'Paus'], [109, 3, '9', 'Copas'], [102, 3, '2', 'Copas'], [102, 5, '2', 'Paus'], [107, 6, '7', 'Espadas'], [112, 6, 'J', 'Espadas'], [110, 3, '10', 'Copas']], [[110, 5, '10', 'Paus'], [101, 3, 'A', 'Copas'], [112, 6, 'J', 'Espadas'], [103, 4, '3', 'Ouro'], [111, 4, 'Q', 'Ouro'], [110, 4, '10', 'Ouro'], [103, 4, '3', 'Ouro']], [[104, 5, '4', 'Paus'], [103, 3, '3', 'Copas'], [104, 3, '4', 'Copas'], [109, 6, '9', 'Espadas'], [109, 6, '9', 'Espadas'], [111, 4, 'Q', 'Ouro'], [102, 6, '2', 'Espadas']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 110
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 3
# Posicao Matriz
# 14
# Posicao Matriz
# 14
# Cartas
# [110, 3, '10', 'Copas']
# Troca Auto - Carta Aleatoria
# Nova carta: 107
# Troca Auto - Naipe Aleatoria
# Novo naipe: 3
# Cartas Trocadas
# Posicao
# 14
# Cartas Trocadas
# [110, 5, '10', 'Paus']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[110, 5, '10', 'Paus'], [109, 3, '9', 'Copas'], [102, 3, '2', 'Copas'], [102, 5, '2', 'Paus'], [107, 6, '7', 'Espadas'], [112, 6, 'J', 'Espadas'], [110, 3, '10', 'Copas']], [[110, 5, '10', 'Paus'], [101, 3, 'A', 'Copas'], [112, 6, 'J', 'Espadas'], [103, 4, '3', 'Ouro'], [111, 4, 'Q', 'Ouro'], [110, 4, '10', 'Ouro'], [103, 4, '3', 'Ouro']], [[107, 3, '7', 'Copas'], [103, 3, '3', 'Copas'], [104, 3, '4', 'Copas'], [109, 6, '9', 'Espadas'], [109, 6, '9', 'Espadas'], [111, 4, 'Q', 'Ouro'], [102, 6, '2', 'Espadas']]]
# Cartas Embaralhadas (21 Cartas)
# [102, 6, '2', 'Espadas']
# [111, 4, 'Q', 'Ouro']
# [109, 6, '9', 'Espadas']
# [109, 6, '9', 'Espadas']
# [104, 3, '4', 'Copas']
# [103, 3, '3', 'Copas']
# [104, 5, '4', 'Paus']
# [103, 4, '3', 'Ouro']
# [110, 4, '10', 'Ouro']
# [111, 4, 'Q', 'Ouro']
# [103, 4, '3', 'Ouro']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [102, 6, '2', 'Espadas']
# [111, 4, 'Q', 'Ouro']
# [109, 6, '9', 'Espadas']
# [109, 6, '9', 'Espadas']
# [104, 3, '4', 'Copas']
# [103, 3, '3', 'Copas']
# [104, 5, '4', 'Paus']
# [103, 4, '3', 'Ouro']
# [110, 4, '10', 'Ouro']
# [111, 4, 'Q', 'Ouro']
# [103, 4, '3', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [101, 3, 'A', 'Copas']
# [110, 5, '10', 'Paus']
# [110, 3, '10', 'Copas']
# [112, 6, 'J', 'Espadas']
# [107, 6, '7', 'Espadas']
# [102, 5, '2', 'Paus']
# [102, 3, '2', 'Copas']
# [109, 3, '9', 'Copas']
# [110, 5, '10', 'Paus']
# [102, 6, '2', 'Espadas']
# [109, 6, '9', 'Espadas']
# [104, 3, '4', 'Copas']
# [112, 5, 'J', 'Paus']
# [107, 5, '7', 'Paus']
# [110, 5, '10', 'Paus']
# [106, 4, '6', 'Ouro']
# [107, 4, '7', 'Ouro']
# [107, 4, '7', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [110, 5, '10', 'Paus']
# [108, 6, '8', 'Espadas']
# [106, 5, '6', 'Paus']
# [101, 6, 'A', 'Espadas']
# [113, 3, 'K', 'Copas']
# [108, 6, '8', 'Espadas']
# [106, 5, '6', 'Paus']
# [112, 6, 'J', 'Espadas']
# [105, 4, '5', 'Ouro']
# [110, 6, '10', 'Espadas']
# [104, 3, '4', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [108, 6, '8', 'Espadas']
# [106, 6, '6', 'Espadas']
# [112, 3, 'J', 'Copas']
# [111, 5, 'Q', 'Paus']
# [107, 6, '7', 'Espadas']
# [110, 3, '10', 'Copas']
# [106, 4, '6', 'Ouro']
# [102, 3, '2', 'Copas']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[111, 3, 'Q', 'Copas'], [106, 6, '6', 'Espadas'], [112, 6, 'J', 'Espadas'], [113, 5, 'K', 'Paus'], [101, 4, 'A', 'Ouro'], [107, 4, '7', 'Ouro'], [112, 3, 'J', 'Copas'], [109, 4, '9', 'Ouro'], [102, 5, '2', 'Paus'], [109, 6, '9', 'Espadas'], [110, 4, '10', 'Ouro'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [103, 6, '3', 'Espadas'], [113, 5, 'K', 'Paus'], [107, 3, '7', 'Copas'], [104, 3, '4', 'Copas'], [113, 4, 'K', 'Ouro'], [107, 4, '7', 'Ouro'], [103, 4, '3', 'Ouro'], [101, 4, 'A', 'Ouro'], [104, 5, '4', 'Paus'], [104, 3, '4', 'Copas'], [109, 5, '9', 'Paus'], [113, 4, 'K', 'Ouro'], [104, 5, '4', 'Paus'], [113, 3, 'K', 'Copas'], [108, 4, '8', 'Ouro'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [105, 3, '5', 'Copas'], [104, 5, '4', 'Paus'], [113, 6, 'K', 'Espadas'], [110, 4, '10', 'Ouro'], [106, 5, '6', 'Paus'], [101, 3, 'A', 'Copas'], [111, 6, 'Q', 'Espadas'], [109, 5, '9', 'Paus'], [105, 3, '5', 'Copas'], [110, 4, '10', 'Ouro'], [111, 4, 'Q', 'Ouro'], [101, 5, 'A', 'Paus'], [112, 4, 'J', 'Ouro'], [109, 3, '9', 'Copas'], [101, 6, 'A', 'Espadas'], [111, 5, 'Q', 'Paus'], [109, 6, '9', 'Espadas'], [111, 6, 'Q', 'Espadas'], [106, 5, '6', 'Paus'], [104, 6, '4', 'Espadas'], [112, 4, 'J', 'Ouro'], [111, 5, 'Q', 'Paus']]
# Cartas Embaralhadas (21 Cartas)
# [111, 3, 'Q', 'Copas']
# [106, 6, '6', 'Espadas']
# [112, 6, 'J', 'Espadas']
# [113, 5, 'K', 'Paus']
# [101, 4, 'A', 'Ouro']
# [107, 4, '7', 'Ouro']
# [112, 3, 'J', 'Copas']
# [109, 4, '9', 'Ouro']
# [102, 5, '2', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 4, '10', 'Ouro']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [103, 6, '3', 'Espadas']
# [113, 5, 'K', 'Paus']
# [107, 3, '7', 'Copas']
# [104, 3, '4', 'Copas']
# [113, 4, 'K', 'Ouro']
# [107, 4, '7', 'Ouro']
# [103, 4, '3', 'Ouro']
# [101, 4, 'A', 'Ouro']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[101, 4, 'A', 'Ouro'], [103, 4, '3', 'Ouro'], [107, 4, '7', 'Ouro'], [113, 4, 'K', 'Ouro'], [104, 3, '4', 'Copas'], [107, 3, '7', 'Copas'], [113, 5, 'K', 'Paus']], [[103, 6, '3', 'Espadas'], [112, 3, 'J', 'Copas'], [111, 6, 'Q', 'Espadas'], [110, 4, '10', 'Ouro'], [109, 6, '9', 'Espadas'], [102, 5, '2', 'Paus'], [109, 4, '9', 'Ouro']], [[112, 3, 'J', 'Copas'], [107, 4, '7', 'Ouro'], [101, 4, 'A', 'Ouro'], [113, 5, 'K', 'Paus'], [112, 6, 'J', 'Espadas'], [106, 6, '6', 'Espadas'], [111, 3, 'Q', 'Copas']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 108
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 4
# Posicao Matriz
# 27
# Posicao Matriz
# 27
# Cartas
# [108, 4, '8', 'Ouro']
# Troca Auto - Carta Aleatoria
# Nova carta: 107
# Troca Auto - Naipe Aleatoria
# Novo naipe: 6
# Posição da carta inválida: 27
# Cartas Trocadas
# Posicao
# 27
# Cartas Trocadas
# [101, 4, 'A', 'Ouro']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[101, 4, 'A', 'Ouro'], [103, 4, '3', 'Ouro'], [107, 4, '7', 'Ouro'], [113, 4, 'K', 'Ouro'], [104, 3, '4', 'Copas'], [107, 3, '7', 'Copas'], [113, 5, 'K', 'Paus']], [[103, 6, '3', 'Espadas'], [112, 3, 'J', 'Copas'], [111, 6, 'Q', 'Espadas'], [110, 4, '10', 'Ouro'], [109, 6, '9', 'Espadas'], [102, 5, '2', 'Paus'], [109, 4, '9', 'Ouro']], [[112, 3, 'J', 'Copas'], [107, 4, '7', 'Ouro'], [101, 4, 'A', 'Ouro'], [113, 5, 'K', 'Paus'], [112, 6, 'J', 'Espadas'], [106, 6, '6', 'Espadas'], [111, 3, 'Q', 'Copas']]]
# Cartas Embaralhadas (21 Cartas)
# [111, 3, 'Q', 'Copas']
# [106, 6, '6', 'Espadas']
# [112, 6, 'J', 'Espadas']
# [113, 5, 'K', 'Paus']
# [101, 4, 'A', 'Ouro']
# [107, 4, '7', 'Ouro']
# [112, 3, 'J', 'Copas']
# [109, 4, '9', 'Ouro']
# [102, 5, '2', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 4, '10', 'Ouro']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [111, 3, 'Q', 'Copas']
# [106, 6, '6', 'Espadas']
# [112, 6, 'J', 'Espadas']
# [113, 5, 'K', 'Paus']
# [101, 4, 'A', 'Ouro']
# [107, 4, '7', 'Ouro']
# [112, 3, 'J', 'Copas']
# [109, 4, '9', 'Ouro']
# [102, 5, '2', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 4, '10', 'Ouro']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [103, 6, '3', 'Espadas']
# [113, 5, 'K', 'Paus']
# [107, 3, '7', 'Copas']
# [104, 3, '4', 'Copas']
# [113, 4, 'K', 'Ouro']
# [107, 4, '7', 'Ouro']
# [103, 4, '3', 'Ouro']
# [101, 4, 'A', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 3, '4', 'Copas']
# [109, 5, '9', 'Paus']
# [113, 4, 'K', 'Ouro']
# [104, 5, '4', 'Paus']
# [113, 3, 'K', 'Copas']
# [108, 4, '8', 'Ouro']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [105, 3, '5', 'Copas']
# [104, 5, '4', 'Paus']
# [113, 6, 'K', 'Espadas']
# [110, 4, '10', 'Ouro']
# [106, 5, '6', 'Paus']
# [101, 3, 'A', 'Copas']
# [111, 6, 'Q', 'Espadas']
# [109, 5, '9', 'Paus']
# [105, 3, '5', 'Copas']
# [110, 4, '10', 'Ouro']
# [111, 4, 'Q', 'Ouro']
# [101, 5, 'A', 'Paus']
# [112, 4, 'J', 'Ouro']
# [109, 3, '9', 'Copas']
# [101, 6, 'A', 'Espadas']
# [111, 5, 'Q', 'Paus']
# [109, 6, '9', 'Espadas']
# [111, 6, 'Q', 'Espadas']
# [106, 5, '6', 'Paus']
# [104, 6, '4', 'Espadas']
# [112, 4, 'J', 'Ouro']
# [111, 5, 'Q', 'Paus']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[107, 4, '7', 'Ouro'], [110, 4, '10', 'Ouro'], [112, 6, 'J', 'Espadas'], [105, 6, '5', 'Espadas'], [110, 5, '10', 'Paus'], [101, 5, 'A', 'Paus'], [106, 6, '6', 'Espadas'], [101, 5, 'A', 'Paus'], [101, 3, 'A', 'Copas'], [104, 6, '4', 'Espadas'], [108, 5, '8', 'Paus'], [107, 3, '7', 'Copas'], [103, 3, '3', 'Copas'], [103, 6, '3', 'Espadas'], [103, 4, '3', 'Ouro'], [109, 4, '9', 'Ouro'], [101, 5, 'A', 'Paus'], [110, 3, '10', 'Copas'], [110, 5, '10', 'Paus'], [111, 6, 'Q', 'Espadas'], [108, 6, '8', 'Espadas'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [103, 3, '3', 'Copas'], [111, 5, 'Q', 'Paus'], [112, 3, 'J', 'Copas'], [110, 4, '10', 'Ouro'], [113, 6, 'K', 'Espadas'], [101, 6, 'A', 'Espadas'], [105, 4, '5', 'Ouro'], [106, 5, '6', 'Paus'], [109, 4, '9', 'Ouro'], [103, 5, '3', 'Paus'], [101, 6, 'A', 'Espadas'], [112, 3, 'J', 'Copas'], [108, 3, '8', 'Copas'], [113, 5, 'K', 'Paus'], [107, 5, '7', 'Paus'], [106, 6, '6', 'Espadas'], [101, 6, 'A', 'Espadas'], [111, 5, 'Q', 'Paus'], [101, 4, 'A', 'Ouro'], [108, 4, '8', 'Ouro'], [106, 4, '6', 'Ouro'], [107, 5, '7', 'Paus'], [109, 6, '9', 'Espadas'], [108, 4, '8', 'Ouro'], [109, 6, '9', 'Espadas'], [104, 6, '4', 'Espadas'], [109, 6, '9', 'Espadas'], [101, 4, 'A', 'Ouro'], [103, 6, '3', 'Espadas']]
# Cartas Embaralhadas (21 Cartas)
# [107, 4, '7', 'Ouro']
# [110, 4, '10', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [105, 6, '5', 'Espadas']
# [110, 5, '10', 'Paus']
# [101, 5, 'A', 'Paus']
# [106, 6, '6', 'Espadas']
# [101, 5, 'A', 'Paus']
# [101, 3, 'A', 'Copas']
# [104, 6, '4', 'Espadas']
# [108, 5, '8', 'Paus']
# [107, 3, '7', 'Copas']
# [103, 3, '3', 'Copas']
# [103, 6, '3', 'Espadas']
# [103, 4, '3', 'Ouro']
# [109, 4, '9', 'Ouro']
# [101, 5, 'A', 'Paus']
# [110, 3, '10', 'Copas']
# [110, 5, '10', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [108, 6, '8', 'Espadas']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[108, 6, '8', 'Espadas'], [111, 6, 'Q', 'Espadas'], [110, 5, '10', 'Paus'], [110, 3, '10', 'Copas'], [101, 5, 'A', 'Paus'], [109, 4, '9', 'Ouro'], [103, 4, '3', 'Ouro']], [[103, 6, '3', 'Espadas'], [103, 3, '3', 'Copas'], [107, 3, '7', 'Copas'], [108, 5, '8', 'Paus'], [104, 6, '4', 'Espadas'], [101, 3, 'A', 'Copas'], [101, 5, 'A', 'Paus']], [[106, 6, '6', 'Espadas'], [101, 5, 'A', 'Paus'], [110, 5, '10', 'Paus'], [105, 6, '5', 'Espadas'], [112, 6, 'J', 'Espadas'], [110, 4, '10', 'Ouro'], [107, 4, '7', 'Ouro']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 101
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 4
# Posicao Matriz
# 41
# Posicao Matriz
# 41
# Cartas
# [101, 4, 'A', 'Ouro']
# Troca Auto - Carta Aleatoria
# Nova carta: 104
# Troca Auto - Naipe Aleatoria
# Novo naipe: 4
# Posição da carta inválida: 41
# Cartas Trocadas
# Posicao
# 41
# Cartas Trocadas
# [108, 6, '8', 'Espadas']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[108, 6, '8', 'Espadas'], [111, 6, 'Q', 'Espadas'], [110, 5, '10', 'Paus'], [110, 3, '10', 'Copas'], [101, 5, 'A', 'Paus'], [109, 4, '9', 'Ouro'], [103, 4, '3', 'Ouro']], [[103, 6, '3', 'Espadas'], [103, 3, '3', 'Copas'], [107, 3, '7', 'Copas'], [108, 5, '8', 'Paus'], [104, 6, '4', 'Espadas'], [101, 3, 'A', 'Copas'], [101, 5, 'A', 'Paus']], [[106, 6, '6', 'Espadas'], [101, 5, 'A', 'Paus'], [110, 5, '10', 'Paus'], [105, 6, '5', 'Espadas'], [112, 6, 'J', 'Espadas'], [110, 4, '10', 'Ouro'], [107, 4, '7', 'Ouro']]]
# Cartas Embaralhadas (21 Cartas)
# [107, 4, '7', 'Ouro']
# [110, 4, '10', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [105, 6, '5', 'Espadas']
# [110, 5, '10', 'Paus']
# [101, 5, 'A', 'Paus']
# [106, 6, '6', 'Espadas']
# [101, 5, 'A', 'Paus']
# [101, 3, 'A', 'Copas']
# [104, 6, '4', 'Espadas']
# [108, 5, '8', 'Paus']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [107, 4, '7', 'Ouro']
# [110, 4, '10', 'Ouro']
# [112, 6, 'J', 'Espadas']
# [105, 6, '5', 'Espadas']
# [110, 5, '10', 'Paus']
# [101, 5, 'A', 'Paus']
# [106, 6, '6', 'Espadas']
# [101, 5, 'A', 'Paus']
# [101, 3, 'A', 'Copas']
# [104, 6, '4', 'Espadas']
# [108, 5, '8', 'Paus']
# [107, 3, '7', 'Copas']
# [103, 3, '3', 'Copas']
# [103, 6, '3', 'Espadas']
# [103, 4, '3', 'Ouro']
# [109, 4, '9', 'Ouro']
# [101, 5, 'A', 'Paus']
# [110, 3, '10', 'Copas']
# [110, 5, '10', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [108, 6, '8', 'Espadas']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [103, 3, '3', 'Copas']
# [111, 5, 'Q', 'Paus']
# [112, 3, 'J', 'Copas']
# [110, 4, '10', 'Ouro']
# [113, 6, 'K', 'Espadas']
# [101, 6, 'A', 'Espadas']
# [105, 4, '5', 'Ouro']
# [106, 5, '6', 'Paus']
# [109, 4, '9', 'Ouro']
# [103, 5, '3', 'Paus']
# [101, 6, 'A', 'Espadas']
# ...
# Cartas Embaralhadas (21 Cartas)
# [101, 3, 'A', 'Copas']
# [111, 3, 'Q', 'Copas']
# [104, 5, '4', 'Paus']
# [104, 5, '4', 'Paus']
# [107, 6, '7', 'Espadas']
# [106, 3, '4', 'Copas']
# [110, 6, '10', 'Espadas']
# [101, 5, 'A', 'Paus']
# [111, 3, 'Q', 'Copas']
# [104, 3, '4', 'Copas']
# [110, 5, '10', 'Paus']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [101, 3, 'A', 'Copas']
# [111, 3, 'Q', 'Copas']
# [104, 5, '4', 'Paus']
# [104, 5, '4', 'Paus']
# [107, 6, '7', 'Espadas']
# [106, 3, '4', 'Copas']
# [110, 6, '10', 'Espadas']
# [101, 5, 'A', 'Paus']
# [111, 3, 'Q', 'Copas']
# [104, 3, '4', 'Copas']
# [110, 5, '10', 'Paus']
# [109, 5, '9', 'Paus']
# [101, 6, 'A', 'Espadas']
# [101, 4, 'A', 'Ouro']
# [102, 6, '2', 'Espadas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 5, 'K', 'Paus']
# [103, 6, '3', 'Espadas']
# [113, 3, 'K', 'Copas']
# [110, 4, '10', 'Ouro']
# [109, 4, '9', 'Ouro']
# [107, 3, '7', 'Copas']
# [101, 3, 'A', 'Copas']
# [106, 5, '6', 'Paus']
# [113, 5, 'K', 'Paus']
# [103, 4, '3', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 4, '7', 'Ouro']
# [104, 5, '4', 'Paus']
# [101, 5, 'A', 'Paus']
# [105, 5, '5', 'Paus']
# [105, 5, '5', 'Paus']
# [102, 5, '2', 'Paus']
# [109, 4, '9', 'Ouro']
# [106, 3, '4', 'Copas']
# [106, 6, '6', 'Espadas']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# [113, 6, 'K', 'Espadas']
# [102, 6, '2', 'Espadas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [108, 3, '8', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 4, 'A', 'Ouro']
# [106, 5, '6', 'Paus']
# [102, 6, '2', 'Espadas']
# [109, 6, '9', 'Espadas']
# [112, 6, 'J', 'Espadas']
# [105, 6, '5', 'Espadas']
# [110, 3, '10', 'Copas']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[112, 3, 'J', 'Copas'], [112, 5, 'J', 'Paus'], [106, 5, '6', 'Paus'], [109, 4, '9', 'Ouro'], [107, 3, '7', 'Copas'], [109, 3, '9', 'Copas'], [106, 4, '6', 'Ouro'], [103, 5, '3', 'Paus'], [108, 4, '8', 'Ouro'], [102, 5, '2', 'Paus'], [104, 6, '4', 'Espadas'], [102, 4, '2', 'Ouro'], [110, 6, '10', 'Espadas'], [109, 4, '9', 'Ouro'], [103, 3, '3', 'Copas'], [107, 4, '7', 'Ouro'], [113, 3, 'K', 'Copas'], [111, 6, 'Q', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [111, 3, 'Q', 'Copas'], [109, 4, '9', 'Ouro'], [108, 6, '8', 'Espadas'], [103, 5, '3', 'Paus'], [103, 3, '3', 'Copas'], [110, 5, '10', 'Paus'], [108, 6, '8', 'Espadas'], [101, 6, 'A', 'Espadas'], [102, 6, '2', 'Espadas'], [110, 3, '10', 'Copas'], [109, 4, '9', 'Ouro'], [103, 4, '3', 'Ouro'], [113, 5, 'K', 'Paus'], [102, 5, '2', 'Paus'], [112, 6, 'J', 'Espadas'], [102, 3, '2', 'Copas'], [107, 4, '7', 'Ouro'], [104, 4, '4', 'Ouro'], [108, 4, '8', 'Ouro'], [108, 3, '8', 'Copas'], [111, 4, 'Q', 'Ouro'], [102, 4, '2', 'Ouro'], [102, 6, '2', 'Espadas'], [104, 5, '4', 'Paus'], [101, 4, 'A', 'Ouro'], [103, 6, '3', 'Espadas'], [109, 4, '9', 'Ouro'], [103, 4, '3', 'Ouro'], [110, 6, '10', 'Espadas'], [111, 5, 'Q', 'Paus'], [113, 6, 'K', 'Espadas'], [108, 6, '8', 'Espadas']]
# Cartas Embaralhadas (21 Cartas)
# [112, 3, 'J', 'Copas']
# [112, 5, 'J', 'Paus']
# [106, 5, '6', 'Paus']
# [109, 4, '9', 'Ouro']
# [107, 3, '7', 'Copas']
# [109, 3, '9', 'Copas']
# [106, 4, '6', 'Ouro']
# [103, 5, '3', 'Paus']
# [108, 4, '8', 'Ouro']
# [102, 5, '2', 'Paus']
# [104, 6, '4', 'Espadas']
# [102, 4, '2', 'Ouro']
# [110, 6, '10', 'Espadas']
# [109, 4, '9', 'Ouro']
# [103, 3, '3', 'Copas']
# [107, 4, '7', 'Ouro']
# [113, 3, 'K', 'Copas']
# [111, 6, 'Q', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [111, 3, 'Q', 'Copas']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[111, 3, 'Q', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 3, 'K', 'Copas'], [111, 6, 'Q', 'Espadas'], [113, 3, 'K', 'Copas'], [107, 4, '7', 'Ouro'], [103, 3, '3', 'Copas']], [[109, 4, '9', 'Ouro'], [110, 6, '10', 'Espadas'], [102, 4, '2', 'Ouro'], [104, 6, '4', 'Espadas'], [102, 5, '2', 'Paus'], [108, 4, '8', 'Ouro'], [103, 5, '3', 'Paus']], [[106, 4, '6', 'Ouro'], [109, 3, '9', 'Copas'], [107, 3, '7', 'Copas'], [109, 4, '9', 'Ouro'], [106, 5, '6', 'Paus'], [112, 5, 'J', 'Paus'], [112, 3, 'J', 'Copas']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 108
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 6
# Posicao Matriz
# 22
# Posicao Matriz
# 22
# Cartas
# [108, 6, '8', 'Espadas']
# Troca Auto - Carta Aleatoria
# Nova carta: 104
# Troca Auto - Naipe Aleatoria
# Novo naipe: 4
# Posição da carta inválida: 22
# Cartas Trocadas
# Posicao
# 22
# Cartas Trocadas
# [111, 3, 'Q', 'Copas']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[111, 3, 'Q', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 3, 'K', 'Copas'], [111, 6, 'Q', 'Espadas'], [113, 3, 'K', 'Copas'], [107, 4, '7', 'Ouro'], [103, 3, '3', 'Copas']], [[109, 4, '9', 'Ouro'], [110, 6, '10', 'Espadas'], [102, 4, '2', 'Ouro'], [104, 6, '4', 'Espadas'], [102, 5, '2', 'Paus'], [108, 4, '8', 'Ouro'], [103, 5, '3', 'Paus']], [[106, 4, '6', 'Ouro'], [109, 3, '9', 'Copas'], [107, 3, '7', 'Copas'], [109, 4, '9', 'Ouro'], [106, 5, '6', 'Paus'], [112, 5, 'J', 'Paus'], [112, 3, 'J', 'Copas']]]
# Cartas Embaralhadas (21 Cartas)
# [112, 3, 'J', 'Copas']
# [112, 5, 'J', 'Paus']
# [106, 5, '6', 'Paus']
# [109, 4, '9', 'Ouro']
# [107, 3, '7', 'Copas']
# [109, 3, '9', 'Copas']
# [106, 4, '6', 'Ouro']
# [103, 5, '3', 'Paus']
# [108, 4, '8', 'Ouro']
# [102, 5, '2', 'Paus']
# [104, 6, '4', 'Espadas']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
# [106, 6, '6', 'Espadas']
# [107, 3, '7', 'Copas']
# [107, 4, '7', 'Ouro']
# [107, 5, '7', 'Paus']
# [107, 6, '7', 'Espadas']
# [108, 3, '8', 'Copas']
# [108, 4, '8', 'Ouro']
# [108, 5, '8', 'Paus']
# [108, 6, '8', 'Espadas']
# [109, 3, '9', 'Copas']
# [109, 4, '9', 'Ouro']
# [109, 5, '9', 'Paus']
# [109, 6, '9', 'Espadas']
# [110, 3, '10', 'Copas']
# [110, 4, '10', 'Ouro']
# [110, 5, '10', 'Paus']
# [110, 6, '10', 'Espadas']
# [111, 3, 'Q', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [111, 5, 'Q', 'Paus']
# [111, 6, 'Q', 'Espadas']
# [112, 3, 'J', 'Copas']
# [112, 4, 'J', 'Ouro']
# [112, 5, 'J', 'Paus']
# [112, 6, 'J', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [113, 5, 'K', 'Paus']
# [113, 6, 'K', 'Espadas']
# Cartas Embaralhadas
# [112, 3, 'J', 'Copas']
# [112, 5, 'J', 'Paus']
# [106, 5, '6', 'Paus']
# [109, 4, '9', 'Ouro']
# [107, 3, '7', 'Copas']
# [109, 3, '9', 'Copas']
# [106, 4, '6', 'Ouro']
# [103, 5, '3', 'Paus']
# [108, 4, '8', 'Ouro']
# [102, 5, '2', 'Paus']
# [104, 6, '4', 'Espadas']
# [102, 4, '2', 'Ouro']
# [110, 6, '10', 'Espadas']
# [109, 4, '9', 'Ouro']
# [103, 3, '3', 'Copas']
# [107, 4, '7', 'Ouro']
# [113, 3, 'K', 'Copas']
# [111, 6, 'Q', 'Espadas']
# [113, 3, 'K', 'Copas']
# [113, 4, 'K', 'Ouro']
# [111, 3, 'Q', 'Copas']
# [109, 4, '9', 'Ouro']
# [108, 6, '8', 'Espadas']
# [103, 5, '3', 'Paus']
# [103, 3, '3', 'Copas']
# [110, 5, '10', 'Paus']
# [108, 6, '8', 'Espadas']
# [101, 6, 'A', 'Espadas']
# [102, 6, '2', 'Espadas']
# [110, 3, '10', 'Copas']
# [109, 4, '9', 'Ouro']
# [103, 4, '3', 'Ouro']
# [113, 5, 'K', 'Paus']
# [102, 5, '2', 'Paus']
# [112, 6, 'J', 'Espadas']
# [102, 3, '2', 'Copas']
# [107, 4, '7', 'Ouro']
# [104, 4, '4', 'Ouro']
# [108, 4, '8', 'Ouro']
# [108, 3, '8', 'Copas']
# [111, 4, 'Q', 'Ouro']
# [102, 4, '2', 'Ouro']
# [102, 6, '2', 'Espadas']
# [104, 5, '4', 'Paus']
# [101, 4, 'A', 'Ouro']
# [103, 6, '3', 'Espadas']
# [109, 4, '9', 'Ouro']
# [103, 4, '3', 'Ouro']
# [110, 6, '10', 'Espadas']
# [111, 5, 'Q', 'Paus']
# [113, 6, 'K', 'Espadas']
# [108, 6, '8', 'Espadas']
# Criando Baralho Auto
# Carregando Baralhos
# [[101, 3, 'A', 'Copas'], [101, 4, 'A', 'Ouro'], [101, 5, 'A', 'Paus'], [101, 6, 'A', 'Espadas'], [102, 3, '2', 'Copas'], [102, 4, '2', 'Ouro'], [102, 5, '2', 'Paus'], [102, 6, '2', 'Espadas'], [103, 3, '3', 'Copas'], [103, 4, '3', 'Ouro'], [103, 5, '3', 'Paus'], [103, 6, '3', 'Espadas'], [104, 3, '4', 'Copas'], [104, 4, '4', 'Ouro'], [104, 5, '4', 'Paus'], [104, 6, '4', 'Espadas'], [105, 3, '5', 'Copas'], [105, 4, '5', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [106, 3, '4', 'Copas'], [106, 4, '6', 'Ouro'], [106, 5, '6', 'Paus'], [106, 6, '6', 'Espadas'], [107, 3, '7', 'Copas'], [107, 4, '7', 'Ouro'], [107, 5, '7', 'Paus'], [107, 6, '7', 'Espadas'], [108, 3, '8', 'Copas'], [108, 4, '8', 'Ouro'], [108, 5, '8', 'Paus'], [108, 6, '8', 'Espadas'], [109, 3, '9', 'Copas'], [109, 4, '9', 'Ouro'], [109, 5, '9', 'Paus'], [109, 6, '9', 'Espadas'], [110, 3, '10', 'Copas'], [110, 4, '10', 'Ouro'], [110, 5, '10', 'Paus'], [110, 6, '10', 'Espadas'], [111, 3, 'Q', 'Copas'], [111, 4, 'Q', 'Ouro'], [111, 5, 'Q', 'Paus'], [111, 6, 'Q', 'Espadas'], [112, 3, 'J', 'Copas'], [112, 4, 'J', 'Ouro'], [112, 5, 'J', 'Paus'], [112, 6, 'J', 'Espadas'], [113, 3, 'K', 'Copas'], [113, 4, 'K', 'Ouro'], [113, 5, 'K', 'Paus'], [113, 6, 'K', 'Espadas']]
# Embaralhando Cartas Resultado
# Embaralhando Naipes
# Carregando Baralhos Embaralhados
# [[104, 6, '4', 'Espadas'], [112, 6, 'J', 'Espadas'], [106, 4, '6', 'Ouro'], [109, 4, '9', 'Ouro'], [105, 5, '5', 'Paus'], [105, 6, '5', 'Espadas'], [108, 3, '8', 'Copas'], [105, 3, '5', 'Copas'], [106, 5, '6', 'Paus'], [102, 6, '2', 'Espadas'], [106, 6, '6', 'Espadas'], [111, 6, 'Q', 'Espadas'], [106, 4, '6', 'Ouro'], [109, 5, '9', 'Paus'], [108, 4, '8', 'Ouro'], [107, 6, '7', 'Espadas'], [107, 6, '7', 'Espadas'], [105, 4, '5', 'Ouro'], [110, 5, '10', 'Paus'], [106, 3, '4', 'Copas'], [108, 5, '8', 'Paus'], [105, 3, '5', 'Copas'], [106, 5, '6', 'Paus'], [104, 4, '4', 'Ouro'], [105, 4, '5', 'Ouro'], [111, 3, 'Q', 'Copas'], [106, 3, '4', 'Copas'], [101, 3, 'A', 'Copas'], [112, 3, 'J', 'Copas'], [101, 4, 'A', 'Ouro'], [105, 6, '5', 'Espadas'], [105, 3, '5', 'Copas'], [102, 5, '2', 'Paus'], [103, 3, '3', 'Copas'], [103, 6, '3', 'Espadas'], [111, 5, 'Q', 'Paus'], [107, 6, '7', 'Espadas'], [110, 6, '10', 'Espadas'], [101, 5, 'A', 'Paus'], [110, 5, '10', 'Paus'], [112, 4, 'J', 'Ouro'], [108, 5, '8', 'Paus'], [112, 5, 'J', 'Paus'], [111, 5, 'Q', 'Paus'], [103, 6, '3', 'Espadas'], [106, 3, '4', 'Copas'], [111, 6, 'Q', 'Espadas'], [102, 3, '2', 'Copas'], [103, 5, '3', 'Paus'], [113, 5, 'K', 'Paus'], [106, 6, '6', 'Espadas'], [103, 6, '3', 'Espadas']]
# Cartas Embaralhadas (21 Cartas)
# [104, 6, '4', 'Espadas']
# [112, 6, 'J', 'Espadas']
# [106, 4, '6', 'Ouro']
# [109, 4, '9', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [108, 3, '8', 'Copas']
# [105, 3, '5', 'Copas']
# [106, 5, '6', 'Paus']
# [102, 6, '2', 'Espadas']
# [106, 6, '6', 'Espadas']
# [111, 6, 'Q', 'Espadas']
# [106, 4, '6', 'Ouro']
# [109, 5, '9', 'Paus']
# [108, 4, '8', 'Ouro']
# [107, 6, '7', 'Espadas']
# [107, 6, '7', 'Espadas']
# [105, 4, '5', 'Ouro']
# [110, 5, '10', 'Paus']
# [106, 3, '4', 'Copas']
# [108, 5, '8', 'Paus']
# Cartas Embaralhadas (21 Cartas Matriz 7x3)
# [[[108, 5, '8', 'Paus'], [106, 3, '4', 'Copas'], [110, 5, '10', 'Paus'], [105, 4, '5', 'Ouro'], [107, 6, '7', 'Espadas'], [107, 6, '7', 'Espadas'], [108, 4, '8', 'Ouro']], [[109, 5, '9', 'Paus'], [106, 4, '6', 'Ouro'], [111, 6, 'Q', 'Espadas'], [106, 6, '6', 'Espadas'], [102, 6, '2', 'Espadas'], [106, 5, '6', 'Paus'], [105, 3, '5', 'Copas']], [[108, 3, '8', 'Copas'], [105, 6, '5', 'Espadas'], [105, 5, '5', 'Paus'], [109, 4, '9', 'Ouro'], [106, 4, '6', 'Ouro'], [112, 6, 'J', 'Espadas'], [104, 6, '4', 'Espadas']]]
# Pesquisa Auto - Carta Aleatoria
# Carta para pesquisa: 104
# Pesquisa Auto - Naipe Aleatoria
# Naipe para pesquisa: 5
# Carta 104 de 5 não encontrada no baralho.
# Posicao Matriz
# -1
# Cartas
# [103, 6, '3', 'Espadas']
# Troca Auto - Carta Aleatoria
# Nova carta: 101
# Troca Auto - Naipe Aleatoria
# Novo naipe: 4
# Posição da carta inválida: -1
# Cartas Trocadas
# Posicao
# -1
# Cartas Trocadas
# [108, 5, '8', 'Paus']
# Cartas Trocadas Pos. 1 a 7 / 8 a 14 / 15 a 21)
# [[[108, 5, '8', 'Paus'], [106, 3, '4', 'Copas'], [110, 5, '10', 'Paus'], [105, 4, '5', 'Ouro'], [107, 6, '7', 'Espadas'], [107, 6, '7', 'Espadas'], [108, 4, '8', 'Ouro']], [[109, 5, '9', 'Paus'], [106, 4, '6', 'Ouro'], [111, 6, 'Q', 'Espadas'], [106, 6, '6', 'Espadas'], [102, 6, '2', 'Espadas'], [106, 5, '6', 'Paus'], [105, 3, '5', 'Copas']], [[108, 3, '8', 'Copas'], [105, 6, '5', 'Espadas'], [105, 5, '5', 'Paus'], [109, 4, '9', 'Ouro'], [106, 4, '6', 'Ouro'], [112, 6, 'J', 'Espadas'], [104, 6, '4', 'Espadas']]]
# Cartas Embaralhadas (21 Cartas)
# [104, 6, '4', 'Espadas']
# [112, 6, 'J', 'Espadas']
# [106, 4, '6', 'Ouro']
# [109, 4, '9', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [108, 3, '8', 'Copas']
# [105, 3, '5', 'Copas']
# [106, 5, '6', 'Paus']
# [102, 6, '2', 'Espadas']
# [106, 6, '6', 'Espadas']
# Cartas do Baralho
# [101, 3, 'A', 'Copas']
# [101, 4, 'A', 'Ouro']
# [101, 5, 'A', 'Paus']
# [101, 6, 'A', 'Espadas']
# [102, 3, '2', 'Copas']
# [102, 4, '2', 'Ouro']
# [102, 5, '2', 'Paus']
# [102, 6, '2', 'Espadas']
# [103, 3, '3', 'Copas']
# [103, 4, '3', 'Ouro']
# [103, 5, '3', 'Paus']
# [103, 6, '3', 'Espadas']
# [104, 3, '4', 'Copas']
# [104, 4, '4', 'Ouro']
# [104, 5, '4', 'Paus']
# [104, 6, '4', 'Espadas']
# [105, 3, '5', 'Copas']
# [105, 4, '5', 'Ouro']
# [105, 5, '5', 'Paus']
# [105, 6, '5', 'Espadas']
# [106, 3, '4', 'Copas']
# [106, 4, '6', 'Ouro']
# [106, 5, '6', 'Paus']
