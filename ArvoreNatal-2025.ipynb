# %%
import random
import time
from IPython.display import display, HTML, Javascript, clear_output

def cor_aleatoria_hsl():
    h = random.randint(0, 360)
    s = random.randint(60, 100)
    l = random.randint(35, 70)
    return f"hsl({h} {s}% {l}%)"

def gerar_arvore_html(altura=12):
    largura_total = altura * 2 + 1
    linhas_html = []

    # FOLHAS
    for i in range(altura):
        stars = ""
        for _ in range(2 * i + 1):
            stars += f'<span style="color:{cor_aleatoria_hsl()};">*</span>'
        
        # numero certo de espaços à esquerda
        espacos = " " * (altura - i - 1)
        linhas_html.append(espacos + stars)

    # TRONCO — sempre centralizado
    tronco_texto = "||"
    espacos_tronco = " " * (altura - 1)
    
    for _ in range(2):
        linhas_html.append(espacos_tronco + f'<span style="color:{cor_aleatoria_hsl()};">{tronco_texto}</span>')

    # gerar bloco centralizado
    conteudo = "\n".join(linhas_html)

    html = f'''
    <div style="width:100%; display:flex; justify-content:center;">
      <pre style="display:inline-block; text-align:left; font-family: monospace; 
                  font-size:14px; line-height:1; white-space:pre;">
{conteudo}
      </pre>
    </div>
    '''

    return html


# LOOP DE ANIMAÇÃO
try:
    while True:
        clear_output(wait=True)
        display(HTML(gerar_arvore_html(12)))
        display(Javascript("window.scrollTo(0, document.body.scrollHeight);"))
        time.sleep(0.25)
except KeyboardInterrupt:
    clear_output()
    print("Animação interrompida.")
# Out:
#     <div style="width:100%; display:flex; justify-content:center;">
#       <pre style="display:inline-block; text-align:left; font-family: monospace;
#                   font-size:14px; line-height:1; white-space:pre;">
#            <span style="color:hsl(254 63% 46%);">*</span>
#           <span style="color:hsl(340 87% 68%);">*</span><span style="color:hsl(174 100% 48%);">*</span><span style="color:hsl(287 95% 63%);">*</span>
#          <span style="color:hsl(76 90% 51%);">*</span><span style="color:hsl(213 92% 57%);">*</span><span style="color:hsl(53 79% 54%);">*</span><span style="color:hsl(243 88% 70%);">*</span><span style="color:hsl(96 75% 55%);">*</span>
#         <span style="color:hsl(324 87% 67%);">*</span><span style="color:hsl(267 87% 44%);">*</span><span style="color:hsl(69 92% 37%);">*</span><span style="color:hsl(79 76% 56%);">*</span><span style="color:hsl(105 73% 42%);">*</span><span style="color:hsl(263 62% 46%);">*</span><span style="color:hsl(134 75% 39%);">*</span>
#        <span style="color:hsl(165 61% 54%);">*</span><span style="color:hsl(59 88% 44%);">*</span><span style="color:hsl(352 97% 65%);">*</span><span style="color:hsl(198 64% 61%);">*</span><span style="color:hsl(333 71% 48%);">*</span><span style="color:hsl(193 85% 46%);">*</span><span style="color:hsl(291 82% 48%);">*</span><span style="color:hsl(164 88% 58%);">*</span><span style="color:hsl(87 66% 70%);">*</span>
#       <span style="color:hsl(290 94% 53%);">*</span><span style="color:hsl(122 88% 35%);">*</span><span style="color:hsl(278 62% 56%);">*</span><span style="color:hsl(232 63% 70%);">*</span><span style="color:hsl(54 72% 66%);">*</span><span style="color:hsl(251 89% 66%);">*</span><span style="color:hsl(21 81% 63%);">*</span><span style="color:hsl(198 92% 67%);">*</span><span style="color:hsl(20 60% 46%);">*</span><span style="color:hsl(248 63% 43%);">*</span><span style="color:hsl(188 79% 52%);">*</span>
#      <span style="color:hsl(205 71% 62%);">*</span><span style="color:hsl(335 79% 57%);">*</span><span style="color:hsl(258 96% 70%);">*</span><span style="color:hsl(108 79% 62%);">*</span><span style="color:hsl(329 68% 54%);">*</span><span style="color:hsl(121 90% 68%);">*</span><span style="color:hsl(252 66% 39%);">*</span><span style="color:hsl(30 79% 38%);">*</span><span style="color:hsl(210 70% 69%);">*</span><span style="color:hsl(272 72% 54%);">*</span><span style="color:hsl(82 90% 37%);">*</span><span style="color:hsl(166 69% 38%);">*</span><span style="color:hsl(189 96% 53%);">*</span>
#     <span style="color:hsl(152 62% 61%);">*</span><span style="color:hsl(273 90% 48%);">*</span><span style="color:hsl(59 89% 51%);">*</span><span style="color:hsl(245 97% 49%);">*</span><span style="color:hsl(256 62% 66%);">*</span><span style="color:hsl(262 95% 43%);">*</span><span style="color:hsl(193 89% 40%);">*</span><span style="color:hsl(196 62% 65%);">*</span><span style="color:hsl(179 68% 52%);">*</span><span style="color:hsl(130 99% 44%);">*</span><span style="color:hsl(206 99% 50%);">*</span><span style="color:hsl(302 99% 67%);">*</span><span style="color:hsl(191 73% 39%);">*</span><span style="color:hsl(66 70% 70%);">*</span><span style="color:hsl(263 86% 68%);">*</span>
#    <span style="color:hsl(328 68% 36%);">*</span><span style="color:hsl(137 97% 69%);">*</span><span style="color:hsl(286 60% 67%);">*</span><span style="color:hsl(224 81% 38%);">*</span><span style="color:hsl(322 62% 38%);">*</span><span style="color:hsl(203 87% 35%);">*</span><span style="color:hsl(112 98% 57%);">*</span><span style="color:hsl(72 90% 65%);">*</span><span style="color:hsl(357 67% 49%);">*</span><span style="color:hsl(327 92% 58%);">*</span><span style="color:hsl(164 78% 35%);">*</span><span style="color:hsl(202 89% 37%);">*</span><span style="color:hsl(118 86% 45%);">*</span><span style="color:hsl(251 90% 68%);">*</span><span style="color:hsl(313 84% 46%);">*</span><span style="color:hsl(68 64% 37%);">*</span><span style="color:hsl(341 88% 51%);">*</span>
#   <span style="color:hsl(67 87% 66%);">*</span><span style="color:hsl(156 78% 43%);">*</span><span style="color:hsl(36 79% 64%);">*</span><span style="color:hsl(310 85% 39%);">*</span><span style="color:hsl(97 80% 42%);">*</span><span style="color:hsl(148 85% 50%);">*</span><span style="color:hsl(310 75% 38%);">*</span><span style="color:hsl(130 86% 55%);">*</span><span style="color:hsl(262 86% 61%);">*</span><span style="color:hsl(340 72% 55%);">*</span><span style="color:hsl(182 78% 44%);">*</span><span style="color:hsl(127 75% 56%);">*</span><span style="color:hsl(31 78% 59%);">*</span><span style="color:hsl(315 96% 70%);">*</span><span style="color:hsl(147 88% 45%);">*</span><span style="color:hsl(198 74% 48%);">*</span><span style="color:hsl(352 96% 43%);">*</span><span style="color:hsl(190 73% 35%);">*</span><span style="color:hsl(284 70% 38%);">*</span>
#  <span style="color:hsl(265 62% 46%);">*</span><span style="color:hsl(313 64% 47%);">*</span><span style="color:hsl(25 82% 56%);">*</span><span style="color:hsl(184 64% 63%);">*</span><span style="color:hsl(243 93% 53%);">*</span><span style="color:hsl(192 100% 42%);">*</span><span style="color:hsl(243 79% 49%);">*</span><span style="color:hsl(80 79% 65%);">*</span><span style="color:hsl(259 71% 38%);">*</span><span style="color:hsl(166 90% 46%);">*</span><span style="color:hsl(98 62% 45%);">*</span><span style="color:hsl(283 93% 67%);">*</span><span style="color:hsl(317 81% 41%);">*</span><span style="color:hsl(7 88% 45%);">*</span><span style="color:hsl(178 60% 65%);">*</span><span style="color:hsl(271 77% 53%);">*</span><span style="color:hsl(138 60% 53%);">*</span><span style="color:hsl(120 60% 36%);">*</span><span style="color:hsl(184 92% 49%);">*</span><span style="color:hsl(48 65% 42%);">*</span><span style="color:hsl(59 65% 47%);">*</span>
# <span style="color:hsl(104 77% 46%);">*</span><span style="color:hsl(16 68% 40%);">*</span><span style="color:hsl(133 69% 60%);">*</span><span style="color:hsl(147 72% 66%);">*</span><span style="color:hsl(180 89% 42%);">*</span><span style="color:hsl(132 73% 45%);">*</span><span style="color:hsl(10 64% 69%);">*</span><span style="color:hsl(169 61% 43%);">*</span><span style="color:hsl(132 87% 42%);">*</span><span style="color:hsl(253 71% 36%);">*</span><span style="color:hsl(184 95% 39%);">*</span><span style="color:hsl(316 62% 60%);">*</span><span style="color:hsl(159 87% 65%);">*</span><span style="color:hsl(113 87% 59%);">*</span><span style="color:hsl(56 68% 41%);">*</span><span style="color:hsl(327 84% 60%);">*</span><span style="color:hsl(340 96% 68%);">*</span><span style="color:hsl(169 65% 61%);">*</span><span style="color:hsl(185 62% 49%);">*</span><span style="color:hsl(0 83% 58%);">*</span><span style="color:hsl(83 89% 44%);">*</span><span style="color:hsl(310 62% 61%);">*</span><span style="color:hsl(241 80% 61%);">*</span>
#            <span style="color:hsl(215 75% 51%);">||</span>
#            <span style="color:hsl(20 99% 59%);">||</span>
#       </pre>
#     </div>
