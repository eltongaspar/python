# %% [markdown]
# <a href="https://colab.research.google.com/github/eltongaspar/python/blob/Advpl/Python_Senai_03_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Atividade 03
#variaveis
nota1 = float()
nota2 = float()
media = ()

#entrada de dados
nota1 = float(input("Informe a Nota 1: "))
nota2 = float(input("Informe a Nota 2: "))

#calculos
media = (nota1 + nota2)/2

if media >= 7:
    print("Aprovado")
else:
    print("Reprovado")

#saida de dados
print("A média é: ", media)
# Out:
# Informe a Nota 1: 10
# Informe a Nota 2: 7
# Aprovado
# A média é:  8.5

# %%
#Atividade 02
#variaveis
numero1 = float()
numero2 = float()

#entrada de dados
numero1 = float(input("Informe o numero 1: "))
numero2 = float(input("Informe o numero 2: "))

#calculos

# analise de condição se
if numero1 == numero2:
    print("O numero 1 é igual ao numero 2")
elif numero1 > numero2:
    print("O numero 1 é maior que o numero 2")
elif numero1 < numero2:
    print("O numero 2 é maior que o numero 1")
# Out:
# Informe o numero 1: 10
# Informe o numero 2: 5
# O numero 1 é maior que o numero 2

# %%
# variaveis
num = int()

#entrada de dados
num = int(input("Informe um númro inteiro: "))

#calculos
if num % 2 == 0:
    print("O numero é par")
else:
    print("O numero é impar")
# Out:
# Informe um númro inteiro: 10
# O numero é par

# %%
#importando bibliotecas
from datetime import date

#variaveis
anonascimento = int()
anoatual = int()
idade = int()


#entrada de dados
anoatual = int(input("Informe o ano atual: "))
anonascimento = int(input("Informe o ano de nascimento: "))

#calculos
idade = anoatual - anonascimento

if idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")

#saida de dados
print("A idade é: ", idade)
# Out:
# Informe o ano atual: 2025
# Informe o ano de nascimento: 2000
# Maior de idade
# A idade é:  25

# %%
# 05
#variaveis
num1 = int()
num2 = int()

#entrada de dados
num1 = int(input("Informe o numero 1: "))
num2 = int(input("Informe o numero 2: "))

#condicional
if num1 == num2:
    print("Os numeros são iguais")
elif num1 != num2:
    print("Os numeros são diferentes")
# Out:
# Informe o numero 1: 10
# Informe o numero 2: 10
# Os numeros são iguais

# %%
import datetime

# Obtém a data atual
hoje = datetime.date.today()

# Extrai o ano da data atual
ano_atual = hoje.year

# Imprime o ano atual
print(f"O ano atual é: {ano_atual}")
# Out:
# O ano atual é: 2025

# %%
# 01
#var
time1 = float()
time2 = float()

#entrada de dados
time1 = float(input("Informe o tempo do time 1: "))
time2 = float(input("Informe o tempo do time 2: "))

#calculos
if time1 == time2:
    print("Empate")
elif time1 > time2:
        print("Time 1 venceu")
elif time1 < time2:
        print("Time 2 venceu")
# Out:
# Informe o tempo do time 1: 10
# Informe o tempo do time 2: 11
# Time 2 venceu

# %%
#var
val_compras = float()
num_prestacoes = int()
valor_prestacao = float()

#entrada de dados
compras = float(input("Informe o valor das compras: "))
num_prestacoes = int(input("Informe o numero de prestações: "))

#calculos
valor_prestacao = compras / num_prestacoes

#saida de dados
print("O valor da prestação é: ", valor_prestacao)
# Out:
# Informe o valor das compras: 100
# Informe o numero de prestações: 10
# O valor da prestação é:  10.0

# %%
#var
idadenadador = int()
categoria = str()

#entrada de dados
idadenadador = int(input("Informe a idade do nadador: "))

#condicional
if idadenadador >= 5 and idadenadador <= 7:
    categoria = "Infantil A"
elif idadenadador >= 8 and idadenadador <= 11:
    categoria = "Infantil B"
elif idadenadador >= 12 and idadenadador <= 13:
    categoria = "Juvenil A"
elif idadenadador >= 14 and idadenadador <= 17:
    categoria = "Juvenil B"
elif idadenadador >= 18:
    categoria = "Adulto"
else:
    categoria = "Não classificada"

print("A categoria é:",categoria)
# Out:
# Informe a idade do nadador: 0
# A categoria é: Não classificada

# %%
#var
num1 = float()
num2 = float()
operacao = str()
resultado = float()

#entrada de dados
num1 = float(input("Informe o numero 1: "))
num2 = float(input("Informe o numero 2: "))
operacao = str(input("Informe a operação: "))

#condicional
if operacao == "+":
    resultado = num1 + num2
elif operacao == "-":
    resultado = num1 - num2
elif operacao == "*":
    resultado = num1 * num2
elif operacao == "/":
    resultado = num1 / num2

print("O resultado é: ", resultado)
# Out:
# Informe o numero 1: 10
# Informe o numero 2: 10
# Informe a operação: +
# O resultado é:  20.0

# %%
# Programa para controle de reservatório de água

# Entrada de dados
altura = float(input("Digite a altura do reservatório (cm): "))
largura = float(input("Digite a largura do reservatório (cm): "))
comprimento = float(input("Digite o comprimento do reservatório (cm): "))
consumo_diario = float(input("Digite o consumo médio diário (litros/dia): "))

# (a) Capacidade total em litros
# 1 litro = 1000 cm³
capacidade_cm3 = altura * largura * comprimento
capacidade_litros = capacidade_cm3 / 1000

# (b) Autonomia em dias
autonomia = capacidade_litros / consumo_diario

# (c) Classificação do consumo
if autonomia < 2:
    classificacao = "Consumo elevado"
elif 2 <= autonomia <= 7:
    classificacao = "Consumo moderado"
else:
    classificacao = "Consumo reduzido"

# Saída de dados
print("\n--- Resultado ---")
print(f"Capacidade total do reservatório: {capacidade_litros:.2f} litros")
print(f"Autonomia do reservatório: {autonomia:.2f} dias")
print(f"Classificação do consumo: {classificacao}")
# Out:
# Digite a altura do reservatório (cm): 20
# Digite a largura do reservatório (cm): 40
# Digite o comprimento do reservatório (cm): 90
# Digite o consumo médio diário (litros/dia): 1
#
# --- Resultado ---
# Capacidade total do reservatório: 72.00 litros
# Autonomia do reservatório: 72.00 dias
# Classificação do consumo: Consumo reduzido
