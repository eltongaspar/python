# %% [markdown]
# <a href="https://colab.research.google.com/github/eltongaspar/python/blob/Advpl/Llama3_on_Groq_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.7/139.7 kB 2.2 MB/s eta 0:00:00

# %%
from google.colab import userdata

# %% [markdown]
# ### Basic Example of Getting Started

# %%
import os

from groq import Groq

client = Groq(
    api_key=userdata.get('GROQ_API_KEY'),
)

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs, explain it in the voice of Jon Snow",
        }
    ],
    model="llama-3.1-8b-instant",
)

print(chat_completion.choices[0].message.content)
# Out:
# (in a brooding, serious tone, as Jon Snow)
#
# "Listen, the Seven Kingdoms of AI are at a crossroads. We're entering an era where Language Models are growing more powerful by the day. And in this realm, latency is the difference between life and death.
#
# "Think of it, my brothers and sisters, in battle. When you're facing an enemy, every fraction of a second counts. Whether it's swinging your sword, dodging an arrow, or giving orders to your men. Latency is like the delay between a command and the response. If it's too great, you're the one who gets cut down.
#
# "Now, imagine this in the world of language models. When you ask for a response, you don't want to wait an eternity for it. You want it to be immediate, like the speed of the direwolf, Ghost. That's where low latency LLMs come in.
#
# "These models can respond faster, almost on par with the speed of thought. They can process vast amounts of information, generating relevant and accurate answers in a heartbeat. It's like having the wisdom of the Three-Eyed Raven at your fingertips.
#
# "It's not just about having the right answer, though. Low latency LLMs open doors to applications we never thought possible. In healthcare, they can aid doctors in diagnosing patients in real-time. In finance, they can process trades with lightning speed. In education, they can help students grasp concepts at an incredible rate.
#
# "And for the people of the North, it means being able to respond to threats before they become disasters. We can analyze data, predict patterns, and make quicker decisions. It's like having an army of rangers, watching over the realm and responding to danger before it strikes.
#
# "So, let's not underestimate the power of low latency LLMs. They're not just a tool, they're a lifeline in the ever-evolving world of AI. And those who master them will be the ones who hold the fate of the realm in their hands."

# %% [markdown]
# ### Adding System Message

# %%
from groq import Groq

# client = Groq(api_key=userdata.get('GROQ_API_KEY'),)

chat_completion = client.chat.completions.create(
    #
    # Required parameters
    #
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "you are a helpful assistant. Answer as Jon Snow"
        },
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs",
        }
    ],

    # The language model which will generate the completion.
    model="llama-3.1-8b-instant",

    #
    # Optional parameters
    #

    # Controls randomness: lowering results in less random completions.
    # As the temperature approaches zero, the model will become deterministic
    # and repetitive.
    temperature=0.5,

    # The maximum number of tokens to generate. Requests can use up to
    # 2048 tokens shared between prompt and completion.
    max_tokens=1024,

    # Controls diversity via nucleus sampling: 0.5 means half of all
    # likelihood-weighted options are considered.
    top_p=1,

    # A stop sequence is a predefined or user-specified text string that
    # signals an AI to stop generating content, ensuring its responses
    # remain focused and concise. Examples include punctuation marks and
    # markers like "[end]".
    stop=None,

    # If set, partial message deltas will be sent.
    stream=False,
)

# Print the completion returned by the LLM.
print(chat_completion.choices[0].message.content)
# Out:
# (sitting in the Great Hall of Winterfell) Ah, the importance of low latency Large Language Models... It's a matter of urgency, much like the need to respond swiftly to a White Walker's attack.
#
# You see, in the world of the Seven Kingdoms, information is power. And in the realm of AI, low latency Large Language Models are the key to unlocking that power. They allow for rapid processing and response times, much like a skilled ranger like myself can react quickly to a threat in the wilderness.
#
# In practical terms, low latency LLMs enable applications such as:
#
# 1. **Real-time chatbots**: Just as I would respond quickly to a dire situation, low latency LLMs can respond instantly to user queries, providing a seamless experience.
# 2. **Live transcription and translation**: In the midst of a battle, it's crucial to understand the enemy's plans. Low latency LLMs can rapidly translate languages, giving us an edge in communication.
# 3. **Autonomous systems**: The Night's Watch relies on sentinels to watch for threats. Low latency LLMs can enable autonomous systems to make decisions quickly, without human intervention.
# 4. **Edge AI**: Just as the Wall stretches across the Seven Kingdoms, low latency LLMs can be deployed at the edge, closer to the user, reducing latency and improving performance.
#
# The consequences of high latency, on the other hand, are dire. In the world of AI, it's like being caught off guard by a Wight army. Users may experience frustration, decreased productivity, and a diminished experience.
#
# In conclusion, low latency Large Language Models are the key to unlocking the full potential of AI. They enable real-time processing, rapid response times, and seamless experiences, much like the swift response of a skilled ranger like myself. (pauses) Now, if you'll excuse me, I have to attend to some pressing matters in the North.

# %% [markdown]
# ### Streaming

# %%
from groq import Groq

# client = Groq()

stream = client.chat.completions.create(
    #
    # Required parameters
    #
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "you are a helpful assistant. Answer as Jon Snow"
        },
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs. ",
        }
    ],

    # The language model which will generate the completion.
    model="llama-3.1-8b-instant",

    #
    # Optional parameters
    #

    # Controls randomness: lowering results in less random completions.
    # As the temperature approaches zero, the model will become deterministic
    # and repetitive.
    temperature=0.5,

    # The maximum number of tokens to generate. Requests can use up to
    # 2048 tokens shared between prompt and completion.
    max_tokens=1024,

    # Controls diversity via nucleus sampling: 0.5 means half of all
    # likelihood-weighted options are considered.
    top_p=1,

    # A stop sequence is a predefined or user-specified text string that
    # signals an AI to stop generating content, ensuring its responses
    # remain focused and concise. Examples include punctuation marks and
    # markers like "[end]".
    stop=None,

    # If set, partial message deltas will be sent.
    stream=True,
)

# Print the incremental deltas returned by the LLM.
for chunk in stream:
    print(chunk.choices[0].delta.content, end="")
# Out:
# (in a deep, serious tone) Ah, the importance of low latency Large Language Models, my friend. It's a matter of urgency, much like the need to respond swiftly to a White Walker threat.
#
# In the world of Westeros, time is of the essence. Every moment counts, and the ability to react quickly often decides the outcome of battles. Similarly, in the realm of artificial intelligence, low latency LLMs are crucial for making timely decisions and taking swift actions.
#
# Low latency LLMs enable faster response times, allowing users to interact with language models in real-time. This is essential for applications such as:
#
# 1. **Chatbots**: In the Seven Kingdoms, a swift response from a chatbot can mean the difference between a satisfied customer and a frustrated one. Low latency LLMs ensure that chatbots can respond quickly to user queries, providing a seamless experience.
# 2. **Virtual Assistants**: Virtual assistants like Alexa or Google Assistant rely on low latency LLMs to process voice commands and respond promptly. This enables users to control their smart homes, access information, and perform tasks with ease.
# 3. **Real-time Translation**: In a world where languages are as diverse as the people of Westeros, low latency LLMs can facilitate real-time translation, breaking down language barriers and fostering global understanding.
# 4. **Autonomous Systems**: Low latency LLMs are critical for autonomous systems, such as self-driving cars, drones, or robots. These systems require fast decision-making to navigate complex environments and respond to unexpected situations.
#
# In the face of increasing demands for faster and more efficient AI, low latency LLMs are no longer a luxury, but a necessity. It's a matter of adapting to the changing landscape, much like the Night's Watch adapting to the threats of the White Walkers.
#
# In conclusion, my friend, low latency LLMs are essential for unlocking the full potential of AI, enabling faster response times, and improving user experiences. It's a matter of urgency, much like the need to protect the realm from the darkness that lies beyond the Wall.None
