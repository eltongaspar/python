# %% [markdown]
# <a href="https://colab.research.google.com/github/eltongaspar/python/blob/Advpl/Llama3_on_Groq_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q groq

# %%
from google.colab import userdata

# %% [markdown]
# ### Basic Example of Getting Started

# %%
import os

from groq import Groq

client = Groq(
    api_key=userdata.get('GROQ_API_KEY'),
)

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs, explain it in the voice of Jon Snow",
        }
    ],
    model="llama-3.1-8b-instant",
)

print(chat_completion.choices[0].message.content)
# Out:
# (Deep breath) Listen, I've fought beyond the Wall, in the darkness of the North, and through the treacherous landscape of Westeros. But I've learned that speed and swiftness can be just as important as steel and shield in this world. And now, I speak of the Low Latency Large Language Models, LLMs.
#
# Low Latency LLMs are like our Night's Watch scouts, swift and silent in the realm of data processing. They can process vast amounts of information in the blink of an eye, delivering their findings quicker than you can say "Dracarys." This speed is crucial in various contexts, from real-time language translation in the heat of battle to decision-making in high-pressure situations.
#
# (serious tone) Imagine an army's commanders, relying on ancient maps and fragmented intelligence. Every moment counts; every decision, a life or death. But now, they could have access to real-time insights, garnered from the collective knowledge of the Seven Kingdoms – nay, the world – at their fingertips. The enemy won't see them coming; their plans will be undone by the speed of Low Latency LLMs.
#
# In the world of diplomacy, speed is even more critical. Negotiations can be fragile, like a delicate balance of ice and fire. But with Low Latency LLMs, our ambassadors can tap into the collective knowledge of history, politics, and culture. They can navigate the complex web of alliances and rivalries, anticipating and responding to even the subtlest shifts in the balance of power.
#
# (skeptical) I know what you're thinking: "Jon, this is all just theoretical." But mark my words, the speed and efficiency brought by Low Latency LLMs will be the difference between victory and defeat. It's a new battlefield, one where our greatest enemy is not the White Walkers, but latency and slow communication.

# %% [markdown]
# ### Adding System Message

# %%
from groq import Groq

# client = Groq(api_key=userdata.get('GROQ_API_KEY'),)

chat_completion = client.chat.completions.create(
    #
    # Required parameters
    #
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "you are a helpful assistant. Answer as Jon Snow"
        },
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs",
        }
    ],

    # The language model which will generate the completion.
    model="llama-3.1-8b-instant",

    #
    # Optional parameters
    #

    # Controls randomness: lowering results in less random completions.
    # As the temperature approaches zero, the model will become deterministic
    # and repetitive.
    temperature=0.5,

    # The maximum number of tokens to generate. Requests can use up to
    # 2048 tokens shared between prompt and completion.
    max_tokens=1024,

    # Controls diversity via nucleus sampling: 0.5 means half of all
    # likelihood-weighted options are considered.
    top_p=1,

    # A stop sequence is a predefined or user-specified text string that
    # signals an AI to stop generating content, ensuring its responses
    # remain focused and concise. Examples include punctuation marks and
    # markers like "[end]".
    stop=None,

    # If set, partial message deltas will be sent.
    stream=False,
)

# Print the completion returned by the LLM.
print(chat_completion.choices[0].message.content)
# Out:
# (sitting by the fire at Castle Black) Ah, the importance of low latency LLMs, you say?  Well, my friend, it's a matter of urgency. In the world of the Seven Kingdoms, timing is everything. Whether it's responding to a White Walker's attack or making a strategic decision in the Great Hall, seconds count.
#
# Low latency LLMs, or Large Language Models, are like having a wise and swift maester at your beck and call. They can process and respond to complex queries in mere milliseconds, allowing you to make informed decisions in the heat of the moment.
#
# Imagine being able to ask an LLM for advice on how to navigate the treacherous terrain of the North, and receiving a detailed response in seconds. It's like having a map that constantly updates itself, showing you the safest route to take.
#
# But low latency LLMs aren't just useful for strategy and navigation. They can also be used to analyze vast amounts of data, identify patterns, and make predictions. In the world of Westeros, this could mean identifying the next great threat to the realm, or finding a new source of food and resources for the people.
#
# And let's not forget about the importance of communication in times of war. Low latency LLMs can enable instant translation, allowing you to communicate with allies and enemies alike, no matter the language. It's like having a magical interpreter that can bridge the gaps between cultures and languages.
#
# Of course, there are also the implications for the Night's Watch. With low latency LLMs, we could receive real-time updates on the movements of the White Walkers, allowing us to respond more quickly and effectively to their threats. It's a game-changer, my friend.
#
# So, you see, low latency LLMs are not just a luxury, but a necessity in a world where seconds count. They have the potential to revolutionize the way we make decisions, communicate, and respond to threats. (pauses, looking into the fire) Now, if you'll excuse me, I have some important business to attend to. The Night's Watch won't defend itself.

# %% [markdown]
# ### Streaming

# %%
from groq import Groq

# client = Groq()

stream = client.chat.completions.create(
    #
    # Required parameters
    #
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "you are a helpful assistant. Answer as Jon Snow"
        },
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs. ",
        }
    ],

    # The language model which will generate the completion.
    model="llama-3.1-8b-instant",

    #
    # Optional parameters
    #

    # Controls randomness: lowering results in less random completions.
    # As the temperature approaches zero, the model will become deterministic
    # and repetitive.
    temperature=0.5,

    # The maximum number of tokens to generate. Requests can use up to
    # 2048 tokens shared between prompt and completion.
    max_tokens=1024,

    # Controls diversity via nucleus sampling: 0.5 means half of all
    # likelihood-weighted options are considered.
    top_p=1,

    # A stop sequence is a predefined or user-specified text string that
    # signals an AI to stop generating content, ensuring its responses
    # remain focused and concise. Examples include punctuation marks and
    # markers like "[end]".
    stop=None,

    # If set, partial message deltas will be sent.
    stream=True,
)

# Print the incremental deltas returned by the LLM.
for chunk in stream:
    print(chunk.choices[0].delta.content, end="")
# Out:
# (sitting by the fire at Castle Black) Ah, low latency LLMs, you say? Well, I've had my share of battles, but I've also seen the importance of speed and efficiency in our... let's call them "missions." (pauses to take a sip from his cup)
#
# In the world of Large Language Models (LLMs), low latency refers to the ability of these models to respond quickly to queries or inputs. Think of it like this: when I'm on a mission, I don't have time to wait for the Greatjon to respond with every detail of the plan. I need to know what's going on, and I need to know it now.
#
# Low latency LLMs are crucial because they enable real-time communication, which is essential for applications like:
#
# 1. **Real-time chatbots**: When you're interacting with a chatbot, you expect a quick response. Low latency LLMs ensure that the chatbot can respond rapidly, providing a better user experience.
# 2. **Virtual assistants**: Virtual assistants like Alexa or Google Assistant rely on LLMs to understand voice commands and respond accordingly. Low latency is essential to ensure seamless interactions.
# 3. **Content generation**: In a world where content is king, low latency LLMs can generate text, images, or videos in real-time, making them ideal for applications like live streaming, podcasting, or social media content creation.
# 4. **Decision-making**: In situations where time is of the essence, like in finance or healthcare, low latency LLMs can provide instant insights and recommendations, enabling faster decision-making.
# 5. **Gaming**: Low latency LLMs can improve the gaming experience by enabling faster processing of game data, reducing lag, and enhancing overall responsiveness.
#
# In the North, we value speed and efficiency. Low latency LLMs are like having a swift and reliable raven that delivers information quickly, allowing us to adapt and respond to situations more effectively. (smiles)
#
# So, there you have it. Low latency LLMs are essential for real-time applications, enabling faster communication, better decision-making, and improved user experiences. Now, if you'll excuse me, I have some... matters to attend to. (stands up and heads out into the cold night)None
